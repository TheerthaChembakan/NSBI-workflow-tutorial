# %% [markdown]
# Train Neural Networks to estimate Likelihood Ratios
# ===
#
# In this notebook we will setup the neural networks that train unbiased and low-variance density ratios to be then used for neural simulation-based inference.

# %%
import os, sys, pathlib, importlib
sys.path.append('../')

# Load the package and modules for training and plotting
import nsbi_common_utils
from nsbi_common_utils import plotting, training, datasets, configuration
from nsbi_common_utils.training import density_ratio_trainer


import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Nadam
import mplhep as hep
import matplotlib.pyplot as plt
import pickle
import yaml
import random

from utils import preselection_using_score, calculate_preselection_observable

from coffea.analysis_tools import PackedSelection

import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

hep.style.use(hep.style.ATLAS)
# Out:
# /home/jsandesara_umass_edu/NSBI-workflow-tutorial/src/nsbi_common_utils/plotting.py:10: FutureWarning: ``set_style`` is deprecated: Naming convention is changing to match mpl. Use ``mplhep.style.use()``.
#   hep.set_style("ATLAS")
# /home/jsandesara_umass_edu/NSBI-workflow-tutorial/src/nsbi_common_utils/training.py:851: SyntaxWarning: invalid escape sequence '\i'
#   Test if \int p_A/p_B x p_B ~ 1
# 2025-11-06 16:15:10.533536: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-11-06 16:15:10.553670: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-11-06 16:15:10.559813: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-06 16:15:10.575374: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
importlib.reload(sys.modules['nsbi_common_utils.configuration'])
from nsbi_common_utils import configuration

# Load the config file to get metadata like training features
config = nsbi_common_utils.configuration.ConfigManager(file_path_string = './config.yml')

# %%
# Input features for training
features, features_scaling = config.get_training_features()

# %% [markdown]
# Statistical Model
# -
#
# The statistical model for the analysis can be written as:
#
# $$p(x|\mu, \alpha) = \frac{1}{\nu(\mu, \alpha)} \sum_c f_c(\mu) \cdot \nu_c(\alpha) \cdot p_c\left(x|\alpha\right)$$
#
# where $c$ stands for the various physics channels that contribute to the final state $x$, **$\mu$ is the signal-strength parameter and $\alpha$ is the vector of nuisance parameters associated with the various systematic uncertainties in the model**. Note that we are assuming that the parameter $\mu$-dependence is known analytically, given by $f(\mu)$ and that we have simulation models for each of the channels $p_c(x)$.
#
# Setting up the test
# -
#
# The objective is to build the test statistic for composite hypothesis testing:
#
# $$t_\mu = -2 \cdot \frac{\text{Pois}(\mathcal{N}_\text{evts}|\mu, \hat{\hat{\alpha}})}{\text{Pois}(\mathcal{N}_\text{evts}|\hat{\mu}, \hat{\alpha})} -2 \cdot \sum_i^{\mathcal{N}_\text{evts}} w_i \times \log \frac{p(x_i|\mu, \hat{\hat{\alpha}})}{p(x_i|\hat{\mu}, \hat{\alpha})} + \sum_m^{N_\text{systs}} \alpha_m^2$$
#
# A direct approach would then be to model the probability density $p(x|\mu, \alpha)$. This can be done using generative models like Normalizing Flows.
#
# In the presence of high-dimensional inputs, including discrete inputs like the number of jets, this is a more difficult task than training probability density *ratios*. We rewrite the test statistic to turn this into a density ratio estimation task:
#
# $$t_\mu = -2 \cdot \frac{\text{Pois}(\mathcal{N}_\text{evts}|\mu, \hat{\hat{\alpha}})}{\text{Pois}(\mathcal{N}_\text{evts}|\hat{\mu}, \hat{\alpha})} -2 \cdot \sum_i^{\mathcal{N}_\text{evts}} w_i \times \log \frac{p(x_i|\mu, \hat{\hat{\alpha}})/p_{ref}(x)}{p(x_i|\hat{\mu}, \hat{\alpha})/p_{ref}(x)} + \sum_m^{N_\text{systs}} \alpha_m^2$$
#
#
# Then using the analytical statistical model:
#
# $$\frac{p(x|\mu, \alpha)}{p_{ref}(x)} = \frac{1}{\nu(\mu, \alpha)} \sum_c f_c(\mu) \cdot \nu_c(\alpha) \cdot \frac{p_c\left(x|\alpha\right)}{p_{ref}(x)}$$
#
# Further rewriting of the model, factorizing out the $\alpha$-dependence gives,
#
# $$\frac{p(x|\mu, \alpha)}{p_{ref}(x)} = \frac{1}{\sum_c G_c(\alpha) \cdot f_c(\mu) \cdot \nu_c} \sum_c f_c(\mu) \cdot G_c(\alpha)\cdot \nu_c \cdot g_c(x|\alpha) \cdot \frac{p_c\left(x\right)}{p_{ref}(x)}$$
#
# Factorized approach:
# --
#
# Instead of training NNs parameterized on $\mu$ and $\alpha$, we use analytical parameterizations to simplify the problem to training only parameter-independent density ratios.
#
# Let's set this up for the toy $H\to \tau\tau$ model we are using. **Neglecting the nuisance parameter dependence ($G_c(\alpha) = g_c(x|\alpha) = 1$), the probability model can be written as**
#
# $$\sum_c f_c(\mu) \cdot \nu_c(\mu) \cdot \frac{p_c\left(x\right)}{p_{ref}(x)} = \mu \cdot \nu_{H \to \tau\tau}(\mu) \cdot  \frac{p_{H \to \tau\tau}\left(x\right)}{p_{ref}(x)} + \nu_{t\bar{t}}(\mu) \cdot  \frac{p_{t\bar{t}}\left(x\right)}{p_{ref}(x)} + \nu_{Z \to \tau\tau}(\mu) \cdot  \frac{p_{Z \to \tau\tau}\left(x\right)}{p_{ref}(x)}$$
#
# In the NSBI approach presented in this tutorial, the density ratio estimation as a function of the various nuisance parameters is factorized from the nominal density ratio estimation, and will be done in the  `Systematic_Uncertainty_Estimation.ipynb` notebook.

# %%
importlib.reload(sys.modules['nsbi_common_utils.datasets'])
from nsbi_common_utils import datasets

branches_to_load = features + ['presel_score']

Datasets = nsbi_common_utils.datasets.datasets(config_path = './config.yml',
                                                branches_to_load =  branches_to_load)

# %%
dataset_incl_dict      = Datasets.load_datasets_from_config(load_systematics = False)

dataset_incl_nominal   = dataset_incl_dict["Nominal"].copy()

dataset_SR_nominal     = Datasets.filter_region_dataset(dataset_incl_nominal,
                                                       region = "SR")

# %% [markdown]
# Density ratio training
# ===
#
# Now we train the NNs for $\frac{p_c}{p_{ref}}(x)$ density ratios to build the full model. Our choice of reference hypothesis, motivated by the search-oriented mixture model described above, would be:
#
# $$p_{ref}(x) = p_{H \to \tau\tau}(x) = \frac{1}{\nu_{H \to \tau\tau}} \frac{d\sigma_{H \to \tau\tau}}{dx} $$
#
# gives the POI $\mu-$parameterized model:
#
# $$\sum_c \left[f_c(\mu) \cdot \frac{p_c\left(x\right)}{p_{ref}(x)} \right]= \mu + \frac{p_{t\bar{t}}\left(x\right)}{p_{H \to \tau\tau}(x)} + \frac{p_{Z \to \tau\tau}\left(x\right)}{p_{H \to \tau\tau}(x)}$$
#
# But this has shown to cause numerical issues, since the ratio corresponding to the $\mu$-scaling signal term is exactly 1. In the absence of additional signal production mechansims, we instead use:
#
# $$p_{ref}(x) = \frac{1}{\nu_{H \to \tau\tau} + \nu_{t\bar{t}}} \left[\frac{d\sigma_{H \to \tau\tau}}{dx} + \frac{d\sigma_{t\bar{t}}}{dx} \right]$$
#
# giving a more numerically stable model:
#
# $$\sum_c \left[f_c(\mu) \cdot \frac{p_c\left(x\right)}{p_{ref}(x)} \right]= \mu \cdot \frac{p_{H \to \tau\tau}\left(x\right)}{p_{ref}(x)} + \frac{p_{t\bar{t}}\left(x\right)}{p_{ref}(x)} + \frac{p_{Z \to \tau\tau}\left(x\right)}{p_{ref}(x)}$$
#
# The task of estimating the $\mu$-parameterized density ratio is thus reduced to estimating three $\mu$-independent density ratios $\frac{p_{H \to \tau\tau}}{p_{ref}}(x)$, $\frac{p_{t\bar{t}}}{p_{ref}}(x)$ and $\frac{p_{Z \to \tau\tau}}{p_{ref}}(x)$ mixed together with an analytical parameterization (hence the name mixture model).
#
# **NB**: This is the same as the *morphing-aware* approach of density ratio estimation in MadMiner

# %%
# Define the processes that make up the mixture model formula for density ratio estimation

PATH_TO_SAVED_DATA = './saved_datasets/'
TRAINING_OUTPUT_PATH = f'{PATH_TO_SAVED_DATA}output_training_nominal/'

# Signal processes in the model
basis_processes = config.get_basis_samples()
print(basis_processes)

ref_processes = config.get_reference_samples()
print(ref_processes)
# Out:
# ['htautau', 'ttbar', 'ztautau']
# ['htautau', 'ttbar']

# %%
importlib.reload(sys.modules['nsbi_common_utils.training'])
from nsbi_common_utils.training import density_ratio_trainer

NN_training_mix_model = {}

use_log_loss = False

# DELETE_EXISTING_MODELS = True
DELETE_EXISTING_MODELS = False

path_to_ratios = {}
path_to_figures = {}
path_to_models = {}

for process_type in basis_processes:

    dataset_mix_model = Datasets.prepare_basis_training_dataset(dataset_SR_nominal, [process_type], dataset_SR_nominal, ref_processes)

    # Save paths
    output_name                     = f'{process_type}'
    output_dir                      = f'{TRAINING_OUTPUT_PATH}general_output_{process_type}'
    path_to_ratios[process_type]    = f'{TRAINING_OUTPUT_PATH}output_ratios_{process_type}/'
    path_to_figures[process_type]   = f'{TRAINING_OUTPUT_PATH}output_figures_{process_type}/'
    path_to_models[process_type]    = f'{TRAINING_OUTPUT_PATH}output_model_params_{process_type}/'

    NN_training_mix_model[process_type] = density_ratio_trainer(dataset_mix_model, 
                                                                   dataset_mix_model['weights_normed'].to_numpy(),
                                                                   dataset_mix_model['train_labels'].to_numpy(),
                                                                   features, 
                                                                   features_scaling, 
                                                                   [process_type, 'ref'], 
                                                                    output_dir, output_name, 
                                                                    path_to_figures=path_to_figures[process_type],
                                                                    path_to_ratios=path_to_ratios[process_type], 
                                                                    path_to_models=path_to_models[process_type],
                                                                    use_log_loss = use_log_loss,
                                                                    delete_existing_models = DELETE_EXISTING_MODELS)

    del dataset_mix_model

# %% [markdown]
# Neural Network architecture
# ===
#
# Here we will start with a multi-layer perceptron (simple feed-forward Neural Network with fully-connected layers). This can be supplemented with more complex architectures like transformers.
#
# After detailed tuning during the off-shell Higgs boson analysis effort, we found that a network with very wide layers ($\geq 1000$) and a depth of less than 10 works best - alongside batch size of a few hundreds and a gradually declining learning rate that starts with a value just large enough to not blow up.

# %% [markdown]
# Starting with the training and validation of the various density ratio:
#
# $$\frac{p_{H\to\tau\tau}(x)}{p_\text{ref}(x)}, \frac{p_{t\bar{t}}(x)}{p_\text{ref}(x)}, \frac{p_{Z \to \tau\tau}(x)}{p_\text{ref}(x)}$$

# %%
print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available: 1

# %%
# You can either train your own NNs (in which case set this to False) or you can load the pre-trained NNs. 
# Training NNs without GPUs can be very slow, for the kind of NNs we need for unbiased estimation of density ratios
USE_SAVED_MODELS = True

# Define unique settings for each process type
doCalibration = False
RECALIBRATE = True
num_bins_cal = 500
scaling_type = 'MinMax'
batch_size = 512
validation_split = 0.1
holdout_split = 0.25

num_epochs = 100
callback_patience = 30

num_layers = 4
num_neurons_per_layer = 1000

num_ensemble_members = 20

verbose_level = 1

PLOT_SCALED_FEATURES = False

CALIBRATION_TYPE = "histogram"

training_settings = {

    'htautau': {
        'hidden_layers':        num_layers,
        'neurons':              num_neurons_per_layer,
        'number_of_epochs':     num_epochs,
        'batch_size':           batch_size,
        'learning_rate':        0.1,
        'scalerType':           scaling_type,
        'calibration':          doCalibration,
        'num_bins_cal':         num_bins_cal,
        'callback':             True,
        'callback_patience':    callback_patience,
        'callback_factor':      0.01,
        'validation_split':     validation_split,
        'holdout_split':        holdout_split,
        'verbose':              verbose_level,
        'plot_scaled_features': PLOT_SCALED_FEATURES,
        'load_trained_models':  USE_SAVED_MODELS,
        'recalibrate_output'   : RECALIBRATE,
        'type_of_calibration'  : CALIBRATION_TYPE,
        'num_ensemble_members': num_ensemble_members,
        'summarize_model': True
    },
    
    'ttbar': {
        'hidden_layers':        num_layers,
        'neurons':              num_neurons_per_layer,
        'number_of_epochs':     num_epochs,
        'batch_size':           batch_size,
        'learning_rate':        0.1,
        'scalerType':           scaling_type,
        'calibration':          doCalibration,
        'num_bins_cal':         num_bins_cal,
        'callback':             True,
        'callback_patience':    callback_patience,
        'callback_factor':      0.01,
        'validation_split':     validation_split,
        'holdout_split':        holdout_split,
        'verbose':              verbose_level,
        'plot_scaled_features': PLOT_SCALED_FEATURES,
        'load_trained_models':  USE_SAVED_MODELS,
        'recalibrate_output'   : RECALIBRATE,
        'type_of_calibration'  : CALIBRATION_TYPE,
        'num_ensemble_members': num_ensemble_members,
        'summarize_model': True
    },
    
    'ztautau': {
        'hidden_layers':        num_layers,
        'neurons':              num_neurons_per_layer,
        'number_of_epochs':     num_epochs,
        'batch_size':           batch_size,
        'learning_rate':        0.1,
        'scalerType':           scaling_type,
        'calibration':          doCalibration,
        'num_bins_cal':         num_bins_cal,
        'callback':             True,
        'callback_patience':    callback_patience,
        'callback_factor':      0.01,
        'validation_split':     validation_split,
        'holdout_split':        holdout_split,
        'verbose':              verbose_level,
        'plot_scaled_features': PLOT_SCALED_FEATURES,
        'load_trained_models':  USE_SAVED_MODELS,
        'recalibrate_output'   : RECALIBRATE,
        'type_of_calibration'  : CALIBRATION_TYPE,
        'num_ensemble_members': num_ensemble_members,
        'summarize_model': True
    }
}

# %%
# Train the density ratio NN

for count, process_type in enumerate(basis_processes):
    
    settings = training_settings[process_type]

    NN_training_mix_model[process_type].train_ensemble(**settings)
    NN_training_mix_model[process_type].test_normalization()
# Out:
# 2025-11-06 16:15:30 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_htautau/
# 2025-11-06 16:15:36 | INFO | Training Logs | Loading existing model for ensemble member 1
# 2025-11-06 16:15:37 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_htautau/
# 2025-11-06 16:15:43 | INFO | Training Logs | Loading existing model for ensemble member 2
# 2025-11-06 16:15:44 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_htautau/
# 2025-11-06 16:15:50 | INFO | Training Logs | Loading existing model for ensemble member 3
# 2025-11-06 16:15:51 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_htautau/
# 2025-11-06 16:15:57 | INFO | Training Logs | Loading existing model for ensemble member 4
# 2025-11-06 16:15:58 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_htautau/
# 2025-11-06 16:16:04 | INFO | Training Logs | Loading existing model for ensemble member 5
# 2025-11-06 16:16:05 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_htautau/
# 2025-11-06 16:16:11 | INFO | Training Logs | Loading existing model for ensemble member 6
# 2025-11-06 16:16:12 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_htautau/
# 2025-11-06 16:16:18 | INFO | Training Logs | Loading existing model for ensemble member 7
# 2025-11-06 16:16:19 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_htautau/
# 2025-11-06 16:16:25 | INFO | Training Logs | Loading existing model for ensemble member 8
# 2025-11-06 16:16:26 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_htautau/
# 2025-11-06 16:16:32 | INFO | Training Logs | Loading existing model for ensemble member 9
# 2025-11-06 16:16:33 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_htautau/
# 2025-11-06 16:16:39 | INFO | Training Logs | Loading existing model for ensemble member 10
# 2025-11-06 16:16:40 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_htautau/
# 2025-11-06 16:16:46 | INFO | Training Logs | Loading existing model for ensemble member 11
# 2025-11-06 16:16:47 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_htautau/
# 2025-11-06 16:16:53 | INFO | Training Logs | Loading existing model for ensemble member 12
# 2025-11-06 16:16:54 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_htautau/
# 2025-11-06 16:16:59 | INFO | Training Logs | Loading existing model for ensemble member 13
# 2025-11-06 16:17:01 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_htautau/
# 2025-11-06 16:17:06 | INFO | Training Logs | Loading existing model for ensemble member 14
# 2025-11-06 16:17:08 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_htautau/
# 2025-11-06 16:17:13 | INFO | Training Logs | Loading existing model for ensemble member 15
# 2025-11-06 16:17:15 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_htautau/
# 2025-11-06 16:17:20 | INFO | Training Logs | Loading existing model for ensemble member 16
# 2025-11-06 16:17:22 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_htautau/
# 2025-11-06 16:17:27 | INFO | Training Logs | Loading existing model for ensemble member 17
# 2025-11-06 16:17:29 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_htautau/
# 2025-11-06 16:17:34 | INFO | Training Logs | Loading existing model for ensemble member 18
# 2025-11-06 16:17:36 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_htautau/
# 2025-11-06 16:17:41 | INFO | Training Logs | Loading existing model for ensemble member 19
# 2025-11-06 16:17:43 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_htautau/
# 2025-11-06 16:17:51 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 0 is 1.0043486209121115
#
#
# 2025-11-06 16:17:54 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 1 is 1.0104655997806968
#
#
# 2025-11-06 16:17:57 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 2 is 1.0044691949081543
#
#
# 2025-11-06 16:18:00 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 3 is 1.0140046068808706
#
#
# 2025-11-06 16:18:02 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 4 is 1.00167168150232
#
#
# 2025-11-06 16:18:05 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 5 is 1.0082246637038463
#
#
# 2025-11-06 16:18:08 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 6 is 1.004812019170902
#
#
# 2025-11-06 16:18:11 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 7 is 1.005617416915841
#
#
# 2025-11-06 16:18:14 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 8 is 0.997745065089168
#
#
# 2025-11-06 16:18:17 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 9 is 1.0117285970641303
#
#
# 2025-11-06 16:18:19 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 10 is 1.0142206717787896
#
#
# 2025-11-06 16:18:22 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 11 is 1.0067400599686307
#
#
# 2025-11-06 16:18:25 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 12 is 1.0044917084592893
#
#
# 2025-11-06 16:18:28 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 13 is 1.0002529193512248
#
#
# 2025-11-06 16:18:31 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 14 is 1.004490139812253
#
#
# 2025-11-06 16:18:33 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 15 is 1.004526894658648
#
#
# 2025-11-06 16:18:36 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 16 is 0.9955706331833851
#
#
# 2025-11-06 16:18:39 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 17 is 1.0031602705836589
#
#
# 2025-11-06 16:18:42 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 18 is 1.0079563458917304
#
#
# 2025-11-06 16:18:45 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 19 is 1.0084214751950484
#
#
# 2025-11-06 16:18:45 | INFO | Training Logs | The sum of PDFs using the whole ensemble is 1.005645929240535
#
#
#
# 2025-11-06 16:18:45 | INFO | Training Logs | starting ensemble training
# 2025-11-06 16:18:45 | INFO | Training Logs | Loading existing model for ensemble member 0
# 2025-11-06 16:18:46 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ttbar/
# 2025-11-06 16:18:49 | INFO | Training Logs | Loading existing model for ensemble member 1
# 2025-11-06 16:18:50 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ttbar/
# 2025-11-06 16:18:54 | INFO | Training Logs | Loading existing model for ensemble member 2
# 2025-11-06 16:18:55 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ttbar/
# 2025-11-06 16:18:58 | INFO | Training Logs | Loading existing model for ensemble member 3
# 2025-11-06 16:18:59 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ttbar/
# 2025-11-06 16:19:02 | INFO | Training Logs | Loading existing model for ensemble member 4
# 2025-11-06 16:19:03 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ttbar/
# 2025-11-06 16:19:07 | INFO | Training Logs | Loading existing model for ensemble member 5
# 2025-11-06 16:19:08 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ttbar/
# 2025-11-06 16:19:11 | INFO | Training Logs | Loading existing model for ensemble member 6
# 2025-11-06 16:19:12 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ttbar/
# 2025-11-06 16:19:16 | INFO | Training Logs | Loading existing model for ensemble member 7
# 2025-11-06 16:19:17 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ttbar/
# 2025-11-06 16:19:20 | INFO | Training Logs | Loading existing model for ensemble member 8
# 2025-11-06 16:19:21 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ttbar/
# 2025-11-06 16:19:24 | INFO | Training Logs | Loading existing model for ensemble member 9
# 2025-11-06 16:19:25 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ttbar/
# 2025-11-06 16:19:29 | INFO | Training Logs | Loading existing model for ensemble member 10
# 2025-11-06 16:19:30 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ttbar/
# 2025-11-06 16:19:33 | INFO | Training Logs | Loading existing model for ensemble member 11
# 2025-11-06 16:19:34 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ttbar/
# 2025-11-06 16:19:38 | INFO | Training Logs | Loading existing model for ensemble member 12
# 2025-11-06 16:19:38 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ttbar/
# 2025-11-06 16:19:42 | INFO | Training Logs | Loading existing model for ensemble member 13
# 2025-11-06 16:19:43 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ttbar/
# 2025-11-06 16:19:46 | INFO | Training Logs | Loading existing model for ensemble member 14
# 2025-11-06 16:19:47 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ttbar/
# 2025-11-06 16:19:51 | INFO | Training Logs | Loading existing model for ensemble member 15
# 2025-11-06 16:19:52 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ttbar/
# 2025-11-06 16:19:55 | INFO | Training Logs | Loading existing model for ensemble member 16
# 2025-11-06 16:19:56 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ttbar/
# 2025-11-06 16:19:59 | INFO | Training Logs | Loading existing model for ensemble member 17
# 2025-11-06 16:20:00 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ttbar/
# 2025-11-06 16:20:04 | INFO | Training Logs | Loading existing model for ensemble member 18
# 2025-11-06 16:20:05 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ttbar/
# 2025-11-06 16:20:08 | INFO | Training Logs | Loading existing model for ensemble member 19
# 2025-11-06 16:20:09 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ttbar/
# 2025-11-06 16:20:14 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 0 is 0.9974967118460675
#
#
# 2025-11-06 16:20:16 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 1 is 1.0004705837562016
#
#
# 2025-11-06 16:20:18 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 2 is 1.000730752167029
#
#
# 2025-11-06 16:20:20 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 3 is 1.0022284273723303
#
#
# 2025-11-06 16:20:21 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 4 is 1.0044967207343594
#
#
# 2025-11-06 16:20:23 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 5 is 0.9986241497978554
#
#
# 2025-11-06 16:20:25 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 6 is 1.0027384565039252
#
#
# 2025-11-06 16:20:27 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 7 is 1.0006877292655838
#
#
# 2025-11-06 16:20:29 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 8 is 1.0012111907434529
#
#
# 2025-11-06 16:20:30 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 9 is 0.9987235886205248
#
#
# 2025-11-06 16:20:32 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 10 is 1.0011504985911945
#
#
# 2025-11-06 16:20:34 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 11 is 0.9988366478060154
#
#
# 2025-11-06 16:20:36 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 12 is 0.9997951834531806
#
#
# 2025-11-06 16:20:38 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 13 is 0.9980368134048874
#
#
# 2025-11-06 16:20:39 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 14 is 1.0003351019692435
#
#
# 2025-11-06 16:20:41 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 15 is 1.0025545356756986
#
#
# 2025-11-06 16:20:43 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 16 is 0.9955320158189029
#
#
# 2025-11-06 16:20:45 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 17 is 1.0012823160249942
#
#
# 2025-11-06 16:20:47 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 18 is 1.0060576094947318
#
#
# 2025-11-06 16:20:48 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 19 is 0.99860875897906
#
#
# 2025-11-06 16:20:48 | INFO | Training Logs | The sum of PDFs using the whole ensemble is 1.000479889601262
#
#
#
# 2025-11-06 16:20:48 | INFO | Training Logs | starting ensemble training
# 2025-11-06 16:20:48 | INFO | Training Logs | Loading existing model for ensemble member 0
# 2025-11-06 16:20:50 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ztautau/
# 2025-11-06 16:20:54 | INFO | Training Logs | Loading existing model for ensemble member 1
# 2025-11-06 16:20:55 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ztautau/
# 2025-11-06 16:20:59 | INFO | Training Logs | Loading existing model for ensemble member 2
# 2025-11-06 16:21:00 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ztautau/
# 2025-11-06 16:21:04 | INFO | Training Logs | Loading existing model for ensemble member 3
# 2025-11-06 16:21:05 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ztautau/
# 2025-11-06 16:21:09 | INFO | Training Logs | Loading existing model for ensemble member 4
# 2025-11-06 16:21:10 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ztautau/
# 2025-11-06 16:21:14 | INFO | Training Logs | Loading existing model for ensemble member 5
# 2025-11-06 16:21:15 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ztautau/
# 2025-11-06 16:21:19 | INFO | Training Logs | Loading existing model for ensemble member 6
# 2025-11-06 16:21:21 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ztautau/
# 2025-11-06 16:21:25 | INFO | Training Logs | Loading existing model for ensemble member 7
# 2025-11-06 16:21:26 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ztautau/
# 2025-11-06 16:21:30 | INFO | Training Logs | Loading existing model for ensemble member 8
# 2025-11-06 16:21:31 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ztautau/
# 2025-11-06 16:21:35 | INFO | Training Logs | Loading existing model for ensemble member 9
# 2025-11-06 16:21:36 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ztautau/
# 2025-11-06 16:21:40 | INFO | Training Logs | Loading existing model for ensemble member 10
# 2025-11-06 16:21:41 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ztautau/
# 2025-11-06 16:21:45 | INFO | Training Logs | Loading existing model for ensemble member 11
# 2025-11-06 16:21:46 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ztautau/
# 2025-11-06 16:21:50 | INFO | Training Logs | Loading existing model for ensemble member 12
# 2025-11-06 16:21:51 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ztautau/
# 2025-11-06 16:21:55 | INFO | Training Logs | Loading existing model for ensemble member 13
# 2025-11-06 16:21:57 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ztautau/
# 2025-11-06 16:22:01 | INFO | Training Logs | Loading existing model for ensemble member 14
# 2025-11-06 16:22:02 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ztautau/
# 2025-11-06 16:22:06 | INFO | Training Logs | Loading existing model for ensemble member 15
# 2025-11-06 16:22:07 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ztautau/
# 2025-11-06 16:22:11 | INFO | Training Logs | Loading existing model for ensemble member 16
# 2025-11-06 16:22:12 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ztautau/
# 2025-11-06 16:22:16 | INFO | Training Logs | Loading existing model for ensemble member 17
# 2025-11-06 16:22:17 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ztautau/
# 2025-11-06 16:22:21 | INFO | Training Logs | Loading existing model for ensemble member 18
# 2025-11-06 16:22:22 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ztautau/
# 2025-11-06 16:22:26 | INFO | Training Logs | Loading existing model for ensemble member 19
# 2025-11-06 16:22:28 | INFO | Training Logs | Reading saved models from ./saved_datasets/output_training_nominal/output_model_params_ztautau/
# 2025-11-06 16:22:34 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 0 is 0.9284915737857127
#
#
# 2025-11-06 16:22:36 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 1 is 0.8950597871267132
#
#
# 2025-11-06 16:22:38 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 2 is 1.0232391112711055
#
#
# 2025-11-06 16:22:40 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 3 is 1.1886829863019832
#
#
# 2025-11-06 16:22:42 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 4 is 1.0554547695274725
#
#
# 2025-11-06 16:22:44 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 5 is 1.0241189497724188
#
#
# 2025-11-06 16:22:46 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 6 is 1.0173023064462665
#
#
# 2025-11-06 16:22:48 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 7 is 1.1381594188912498
#
#
# 2025-11-06 16:22:51 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 8 is 0.9974048760945989
#
#
# 2025-11-06 16:22:53 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 9 is 0.9965048830115708
#
#
# 2025-11-06 16:22:55 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 10 is 1.0137776064483388
#
#
# 2025-11-06 16:22:57 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 11 is 1.006823069965053
#
#
# 2025-11-06 16:22:59 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 12 is 0.9998916220308134
#
#
# 2025-11-06 16:23:01 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 13 is 0.9008264431929194
#
#
# 2025-11-06 16:23:03 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 14 is 1.0378518711026194
#
#
# 2025-11-06 16:23:05 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 15 is 0.8960706828549865
#
#
# 2025-11-06 16:23:07 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 16 is 0.9900271934372914
#
#
# 2025-11-06 16:23:10 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 17 is 1.1797297577473473
#
#
# 2025-11-06 16:23:12 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 18 is 0.9959913102760672
#
#
# 2025-11-06 16:23:14 | INFO | Training Logs |
#
#
# The sum of PDFs in ensemble member 19 is 1.0182193201935885
#
#
# 2025-11-06 16:23:14 | INFO | Training Logs | The sum of PDFs using the whole ensemble is 1.0151813769739058

# %% [markdown]
# Check for overtraining by comparing the NN output distributions between training and holdout datasets. The holdout dataset is the subset of events not used during training.

# %%
for process_type in basis_processes:
    NN_training_mix_model[process_type].make_overfit_plots()

# %% [markdown]
# Diagnostic Checks
# ===
#
# While traditionally, a NN observable is judged on the basis of its accuracy - for NSBI we are interested in the quality of the density ratios more than the discrimination power. The latter comes from the perfect modelling of the multi-dimensional likelihood ratios.
#
# To ensure correct modelling, we run two main checks on the training:
#
# - **Calibration closure test**
#
#   The NNs are trained using the binary cross-entropy loss, which under ideal conditions leads to the NN converging to the score function:
#
#   $$\hat{s}_\text{pred} = \frac{p_\text{ref}(x)}{p_\text{ref}(x)+p_\text{c}(x)}$$
#
#   that can be converted into the probability ratio we desire (likelihood ratio trick):
#
#   $$\frac{p_\text{c}(x)}{p_\text{ref}(x)} = \frac{\hat{s}_\text{pred}(x)}{1-\hat{s}_\text{pred}(x)}$$
#
#   For the NNs to be well-calibrated, we use the Monte Carlo samples to verify the equality:
#
#
#   $$\left[\frac{p_c(x)}{p_c(x)+p_{ref}(x)}\right]_\text{NN} \sim \left[\frac{\mathcal{N}_c^{I(x|\hat{s}_\text{pred})}}{\mathcal{N}_c^{I(x|\hat{s}_\text{pred})}+\mathcal{N}_\text{ref}^{I(x|\hat{s}_\text{pred})}}\right]_\text{MC}$$
#
#   where we bin the events from $p_c$ and $p_\text{ref}$ MC samples, denoted by $\mathcal{N}_c^{I(x|\hat{s}_\text{pred})}$ and $\mathcal{N}_\text{ref}^{I(x|\hat{s}_\text{pred})}$ respectively where $I(x|\hat{s}_\text{pred})$ returns the index of the $\hat{s}_\text{pred}$ bin in which an event $x$ falls.

# %%
num_bins_cal = 50

for process_type in basis_processes:
    NN_training_mix_model[process_type].make_calib_plots(nbins=num_bins_cal, observable='score')

# %%
num_bins_cal = 50

for process_type in basis_processes:
    NN_training_mix_model[process_type].make_calib_plots(nbins=num_bins_cal, observable='llr')

# %% [markdown]
# ## Density ratio reweighting closure tests
#
#   Despite having a well-calibrated output and thus a robust probabilistic interpretation, the trained density ratios might not capture the full multi-dimensional event information $x$. In other words, the NNs might still be biased estimators of the optimal score function, as defined in the CARL paper (link).
#
#   The next diagnostic involves verifying the following equality using 1D projections of $x$:
#
#   $$\frac{p_c(x)}{p_{ref}(x)} \times p_{ref}(x) \sim p_c(x)$$
#
#   We can do this one-by-one for all the observables used to model the density ratios, and also possibly the observables not used directly in the training but can still be well-estimated due to the NN learning the right physics.

# %%
variables_to_plot=['log_DER_pt_h'] # The 1D variable for reweighting closure
yscale_type='log'
num_bins_plotting=21

for process_type in basis_processes:

    NN_training_mix_model[process_type].make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)

# %%
dataset_combined_SR = Datasets.merge_dataframe_dict_for_training(dataset_SR_nominal, None, 
                                                                samples_to_merge = ["htautau", "ztautau", "ttbar"])

# %%
path_to_saved_ratios = {}

for process_type in basis_processes:
    # Evaluate the density ratios p_c/p_ref for the full dataset and save for the inference step
    path_to_saved_ratios[process_type] = NN_training_mix_model[process_type].evaluate_and_save_ratios(dataset_combined_SR, 
                                                                                                     aggregation_type = 'median_score')
# Out:
# 2025-11-06 16:23:27 | INFO | Training Logs | Evaluating density ratios
# 2025-11-06 16:24:11 | INFO | Training Logs | Evaluating density ratios
# 2025-11-06 16:24:55 | INFO | Training Logs | Evaluating density ratios

# %%
# Density ratio paths to put in the config file
path_to_saved_ratios
# Out:
# {'htautau': './saved_datasets/output_training_nominal/output_ratios_htautau/ratio_htautau.npy',
#  'ttbar': './saved_datasets/output_training_nominal/output_ratios_ttbar/ratio_ttbar.npy',
#  'ztautau': './saved_datasets/output_training_nominal/output_ratios_ztautau/ratio_ztautau.npy'}

# %%
# Optionally save the dataframe in the same order used to evaluate the density ratios for diagnostics

path_to_save = f"{PATH_TO_SAVED_DATA}/dataset_Asimov.root"
nsbi_common_utils.datasets.save_dataframe_as_root(dataset_combined_SR, 
                                                  path_to_save = path_to_save,
                                                  tree_name = "nominal")

# %%
# Asimov weights correspond to the expected weight vector in the same shape and order as the evaluated density ratios
# This is used in the weighted NLL fits for expected sensitivity and coverage computations

path_to_save = f"{PATH_TO_SAVED_DATA}/asimov_weights.npy"
np.save(f"{path_to_save}", dataset_combined_SR["weights"].to_numpy())

# %%
# Path to put in the config file for inference
path_to_save
# Out:
# './saved_datasets//asimov_weights.npy'

# %% [markdown]
# Systematic Uncertainty Modelling
# ===
#
# So far we have left out the nuisance parameter piece of the parameterized density ratio decomposition shown before:
#
# $$g_c(x|\alpha) = \frac{p_c(x|\alpha)}{p_c(x)}$$
#
# which will be estimated in the `Systematic_Uncertainty_Estimation.ipynb` notebook.

# %% [markdown]
# Training an Ensemble of NNs
# ===
#
# In a realistic analysis, a large ensemble of NNs are trained to estimate density ratios, for *each* of the channels. **This reduces not only the variance but has also been found to reduce biases in the final fits.**
#
# In the off-shell Higgs boson analysis, we used k-fold cross-validation, with k=10, to train an ensemble $N_{ens}\sim 250$ of NNs per density ratio $p_c(x)/p_{ref}(x)$. The density ratios used in the final fit are always evaluated on the holdout dataset and by using each of the folds as holdout once, the entire model for $p_c(x)/p_{ref}(x)$ consists of $N_{ens}\times k \sim 2500$ NNs. Each NN in the ensemble is trained by resampling data without replacement from the k-1 folds used for training.
