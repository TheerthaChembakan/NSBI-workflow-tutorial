# %% [markdown]
# Train Neural Networks to estimate Likelihood Ratios
# ===
#
# In this notebook we will setup the neural networks that train unbiased and low-variance density ratios to be then used for neural simulation-based inference.

# %%
import os, sys, pathlib, importlib
sys.path.append('../')

# Load the package and modules for training and plotting
import nsbi_common_utils
from nsbi_common_utils import plotting, training, datasets, configuration
from nsbi_common_utils.training import density_ratio_trainer, TrainEvaluatePreselNN


import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Nadam
import mplhep as hep
import matplotlib.pyplot as plt
import pickle
import yaml
import random

from utils import preselection_using_score, calculate_preselection_observable

from coffea.analysis_tools import PackedSelection

import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

hep.style.use(hep.style.ATLAS)
# Out:
# /home/jsandesara_umass_edu/NSBI-workflow-tutorial/src/nsbi_common_utils/plotting.py:10: FutureWarning: ``set_style`` is deprecated: Naming convention is changing to match mpl. Use ``mplhep.style.use()``.
#   hep.set_style("ATLAS")
# 2025-11-04 19:12:38.339483: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-11-04 19:12:38.359758: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-11-04 19:12:38.365941: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-04 19:12:38.381334: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
importlib.reload(sys.modules['nsbi_common_utils.configuration'])
from nsbi_common_utils import configuration

# Load the config file to get metadata like training features
config = nsbi_common_utils.configuration.ConfigManager(file_path_string = './config.yml')

# %%
# Input features for training
features, features_scaling = config.get_training_features()

# %% [markdown]
# Statistical Model
# -
#
# The statistical model for the analysis can be written as:
#
# $$p(x|\mu, \alpha) = \frac{1}{\nu(\mu, \alpha)} \sum_c f_c(\mu) \cdot \nu_c(\alpha) \cdot p_c\left(x|\alpha\right)$$
#
# where $c$ stands for the various physics channels that contribute to the final state $x$, **$\mu$ is the signal-strength parameter and $\alpha$ is the vector of nuisance parameters associated with the various systematic uncertainties in the model**. Note that we are assuming that the parameter $\mu$-dependence is known analytically, given by $f(\mu)$ and that we have simulation models for each of the channels $p_c(x)$.
#
# Setting up the test
# -
#
# The objective is to build the test statistic for composite hypothesis testing:
#
# $$t_\mu = -2 \cdot \frac{\text{Pois}(\mathcal{N}_\text{evts}|\mu, \hat{\hat{\alpha}})}{\text{Pois}(\mathcal{N}_\text{evts}|\hat{\mu}, \hat{\alpha})} -2 \cdot \sum_i^{\mathcal{N}_\text{evts}} w_i \times \log \frac{p(x_i|\mu, \hat{\hat{\alpha}})}{p(x_i|\hat{\mu}, \hat{\alpha})} + \sum_m^{N_\text{systs}} \alpha_m^2$$
#
# A direct approach would then be to model the probability density $p(x|\mu, \alpha)$. This can be done using generative models like Normalizing Flows.
#
# In the presence of high-dimensional inputs, including discrete inputs like the number of jets, this is a more difficult task than training probability density *ratios*. We rewrite the test statistic to turn this into a density ratio estimation task:
#
# $$t_\mu = -2 \cdot \frac{\text{Pois}(\mathcal{N}_\text{evts}|\mu, \hat{\hat{\alpha}})}{\text{Pois}(\mathcal{N}_\text{evts}|\hat{\mu}, \hat{\alpha})} -2 \cdot \sum_i^{\mathcal{N}_\text{evts}} w_i \times \log \frac{p(x_i|\mu, \hat{\hat{\alpha}})/p_{ref}(x)}{p(x_i|\hat{\mu}, \hat{\alpha})/p_{ref}(x)} + \sum_m^{N_\text{systs}} \alpha_m^2$$
#
#
# Then using the analytical statistical model:
#
# $$\frac{p(x|\mu, \alpha)}{p_{ref}(x)} = \frac{1}{\nu(\mu, \alpha)} \sum_c f_c(\mu) \cdot \nu_c(\alpha) \cdot \frac{p_c\left(x|\alpha\right)}{p_{ref}(x)}$$
#
# Further rewriting of the model, factorizing out the $\alpha$-dependence gives,
#
# $$\frac{p(x|\mu, \alpha)}{p_{ref}(x)} = \frac{1}{\sum_c G_c(\alpha) \cdot f_c(\mu) \cdot \nu_c} \sum_c f_c(\mu) \cdot G_c(\alpha)\cdot \nu_c \cdot g_c(x|\alpha) \cdot \frac{p_c\left(x\right)}{p_{ref}(x)}$$
#
# Factorized approach:
# --
#
# Instead of training NNs parameterized on $\mu$ and $\alpha$, we use analytical parameterizations to simplify the problem to training only parameter-independent density ratios.
#
# Let's set this up for the toy $H\to \tau\tau$ model we are using. **Neglecting the nuisance parameter dependence ($G_c(\alpha) = g_c(x|\alpha) = 1$), the probability model can be written as**
#
# $$\sum_c f_c(\mu) \cdot \nu_c(\mu) \cdot \frac{p_c\left(x\right)}{p_{ref}(x)} = \mu \cdot \nu_{H \to \tau\tau}(\mu) \cdot  \frac{p_{H \to \tau\tau}\left(x\right)}{p_{ref}(x)} + \nu_{t\bar{t}}(\mu) \cdot  \frac{p_{t\bar{t}}\left(x\right)}{p_{ref}(x)} + \nu_{Z \to \tau\tau}(\mu) \cdot  \frac{p_{Z \to \tau\tau}\left(x\right)}{p_{ref}(x)}$$
#
# In the NSBI approach presented in this tutorial, the density ratio estimation as a function of the various nuisance parameters is factorized from the nominal density ratio estimation, and will be done in the  `Systematic_Uncertainty_Estimation.ipynb` notebook.

# %%
importlib.reload(sys.modules['nsbi_common_utils.datasets'])
from nsbi_common_utils import datasets

branches_to_load = features + ['presel_score']

Datasets = nsbi_common_utils.datasets.datasets(config_path = './config.yml',
                                                branches_to_load =  branches_to_load)

# %%
dataset_incl_dict      = Datasets.load_datasets_from_config(load_systematics = False)

dataset_incl_nominal   = dataset_incl_dict["Nominal"].copy()

dataset_SR_nominal     = Datasets.filter_region_dataset(dataset_incl_nominal,
                                                       region = "SR")

# %% [markdown]
# Density ratio training
# ===
#
# Now we train the NNs for $\frac{p_c}{p_{ref}}(x)$ density ratios to build the full model. Our choice of reference hypothesis, motivated by the search-oriented mixture model described above, would be:
#
# $$p_{ref}(x) = p_{H \to \tau\tau}(x) = \frac{1}{\nu_{H \to \tau\tau}} \frac{d\sigma_{H \to \tau\tau}}{dx} $$
#
# gives the POI $\mu-$parameterized model:
#
# $$\sum_c \left[f_c(\mu) \cdot \frac{p_c\left(x\right)}{p_{ref}(x)} \right]= \mu + \frac{p_{t\bar{t}}\left(x\right)}{p_{H \to \tau\tau}(x)} + \frac{p_{Z \to \tau\tau}\left(x\right)}{p_{H \to \tau\tau}(x)}$$
#
# But this has shown to cause numerical issues, since the ratio corresponding to the $\mu$-scaling signal term is exactly 1. In the absence of additional signal production mechansims, we instead use:
#
# $$p_{ref}(x) = \frac{1}{\nu_{H \to \tau\tau} + \nu_{t\bar{t}}} \left[\frac{d\sigma_{H \to \tau\tau}}{dx} + \frac{d\sigma_{t\bar{t}}}{dx} \right]$$
#
# giving a more numerically stable model:
#
# $$\sum_c \left[f_c(\mu) \cdot \frac{p_c\left(x\right)}{p_{ref}(x)} \right]= \mu \cdot \frac{p_{H \to \tau\tau}\left(x\right)}{p_{ref}(x)} + \frac{p_{t\bar{t}}\left(x\right)}{p_{ref}(x)} + \frac{p_{Z \to \tau\tau}\left(x\right)}{p_{ref}(x)}$$
#
# The task of estimating the $\mu$-parameterized density ratio is thus reduced to estimating three $\mu$-independent density ratios $\frac{p_{H \to \tau\tau}}{p_{ref}}(x)$, $\frac{p_{t\bar{t}}}{p_{ref}}(x)$ and $\frac{p_{Z \to \tau\tau}}{p_{ref}}(x)$ mixed together with an analytical parameterization (hence the name mixture model).
#
# **NB**: This is the same as the *morphing-aware* approach of density ratio estimation in MadMiner

# %%
# Define the processes that make up the mixture model formula for density ratio estimation

PATH_TO_SAVED_DATA = './saved_datasets/'
TRAINING_OUTPUT_PATH = f'{PATH_TO_SAVED_DATA}output_training_nominal/'

# Signal processes in the model
basis_processes = config.get_basis_samples()
print(basis_processes)

ref_processes = config.get_reference_samples()
print(ref_processes)
# Out:
# ['htautau', 'ttbar', 'ztautau']
# ['ttbar', 'ztautau']

# %%
importlib.reload(sys.modules['nsbi_common_utils.training'])
from nsbi_common_utils.training import density_ratio_trainer

NN_training_mix_model = {}

use_log_loss = False

# DELETE_EXISTING_MODELS = True
DELETE_EXISTING_MODELS = False

path_to_ratios = {}
path_to_figures = {}
path_to_models = {}

for process_type in basis_processes:

    dataset_mix_model = Datasets.prepare_basis_training_dataset(dataset_SR_nominal, [process_type], ref_processes)

    # Save paths
    output_name                     = f'{process_type}'
    output_dir                      = f'{TRAINING_OUTPUT_PATH}general_output_{process_type}'
    path_to_ratios[process_type]    = f'{TRAINING_OUTPUT_PATH}output_ratios_{process_type}/'
    path_to_figures[process_type]   = f'{TRAINING_OUTPUT_PATH}output_figures_{process_type}/'
    path_to_models[process_type]    = f'{TRAINING_OUTPUT_PATH}output_model_params_{process_type}/'

    NN_training_mix_model[process_type] = density_ratio_trainer(dataset_mix_model, 
                                                                   dataset_mix_model['weights_normed'].to_numpy(),
                                                                   dataset_mix_model['train_labels'].to_numpy(),
                                                                   features, 
                                                                   features_scaling, 
                                                                   [process_type, 'ref'], 
                                                                    output_dir, output_name, 
                                                                    path_to_figures=path_to_figures[process_type],
                                                                    path_to_ratios=path_to_ratios[process_type], 
                                                                    path_to_models=path_to_models[process_type],
                                                                    use_log_loss = use_log_loss,
                                                                    delete_existing_models = DELETE_EXISTING_MODELS)

    del dataset_mix_model

# %% [markdown]
# Neural Network architecture
# ===
#
# Here we will start with a multi-layer perceptron (simple feed-forward Neural Network with fully-connected layers). This can be supplemented with more complex architectures like transformers.
#
# After detailed tuning during the off-shell Higgs boson analysis effort, we found that a network with very wide layers ($\geq 1000$) and a depth of less than 10 works best - alongside batch size of a few hundreds and a gradually declining learning rate that starts with a value just large enough to not blow up.

# %% [markdown]
# Starting with the training and validation of the various density ratio:
#
# $$\frac{p_{H\to\tau\tau}(x)}{p_\text{ref}(x)}, \frac{p_{t\bar{t}}(x)}{p_\text{ref}(x)}, \frac{p_{Z \to \tau\tau}(x)}{p_\text{ref}(x)}$$

# %%
print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available: 1

# %%
# You can either train your own NNs (in which case set this to False) or you can load the pre-trained NNs. 
# Training NNs without GPUs can be very slow, for the kind of NNs we need for unbiased estimation of density ratios
USE_SAVED_MODELS = False

# Define unique settings for each process type
doCalibration = True
RECALIBRATE = True
num_bins_cal = 500
scaling_type = 'MinMax'
batch_size = 512
validation_split = 0.1
holdout_split = 0.25

num_epochs = 100
callback_patience = 30

num_layers = 4
num_neurons_per_layer = 1000

num_ensemble_members = 1

verbose_level = 1

PLOT_SCALED_FEATURES = False

CALIBRATION_TYPE = "histogram"

training_settings = {

    'htautau': {
        'hidden_layers':        num_layers,
        'neurons':              num_neurons_per_layer,
        'number_of_epochs':     num_epochs,
        'batch_size':           batch_size,
        'learning_rate':        0.1,
        'scalerType':           scaling_type,
        'calibration':          doCalibration,
        'num_bins_cal':         num_bins_cal,
        'callback':             True,
        'callback_patience':    callback_patience,
        'callback_factor':      0.01,
        'validation_split':     validation_split,
        'holdout_split':        holdout_split,
        'verbose':              verbose_level,
        'plot_scaled_features': PLOT_SCALED_FEATURES,
        'load_trained_models':  USE_SAVED_MODELS,
        'recalibrate_output'   : RECALIBRATE,
        'type_of_calibration'  : CALIBRATION_TYPE,
        'num_ensemble_members': num_ensemble_members
    },
    
    'ttbar': {
        'hidden_layers':        num_layers,
        'neurons':              num_neurons_per_layer,
        'number_of_epochs':     num_epochs,
        'batch_size':           batch_size,
        'learning_rate':        0.1,
        'scalerType':           scaling_type,
        'calibration':          doCalibration,
        'num_bins_cal':         num_bins_cal,
        'callback':             True,
        'callback_patience':    callback_patience,
        'callback_factor':      0.01,
        'validation_split':     validation_split,
        'holdout_split':        holdout_split,
        'verbose':              verbose_level,
        'plot_scaled_features': PLOT_SCALED_FEATURES,
        'load_trained_models':  USE_SAVED_MODELS,
        'recalibrate_output'   : RECALIBRATE,
        'type_of_calibration'  : CALIBRATION_TYPE,
        'num_ensemble_members': num_ensemble_members
    },
    
    'ztautau': {
        'hidden_layers':        num_layers,
        'neurons':              num_neurons_per_layer,
        'number_of_epochs':     num_epochs,
        'batch_size':           batch_size,
        'learning_rate':        0.1,
        'scalerType':           scaling_type,
        'calibration':          doCalibration,
        'num_bins_cal':         num_bins_cal,
        'callback':             True,
        'callback_patience':    callback_patience,
        'callback_factor':      0.01,
        'validation_split':     validation_split,
        'holdout_split':        holdout_split,
        'verbose':              verbose_level,
        'plot_scaled_features': PLOT_SCALED_FEATURES,
        'load_trained_models':  USE_SAVED_MODELS,
        'recalibrate_output'   : RECALIBRATE,
        'type_of_calibration'  : CALIBRATION_TYPE,
        'num_ensemble_members': num_ensemble_members
    }
}

# %%
# Train the density ratio NN
for process_type in basis_processes:
    
    settings = training_settings[process_type]

    NN_training_mix_model[process_type].train_ensemble(**settings)
    NN_training_mix_model[process_type].test_normalization()
# Out:
# starting ensemble training
# Sum of weights of class 0: 0.7500188978478306
# Sum of weights of class 1: 0.7500010679428412
# Using swish activation function
# /home/jsandesara_umass_edu/NSBI-workflow-tutorial/.pixi/envs/nsbi-env-gpu/lib/python3.12/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-11-04 19:12:57.437238: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10525 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:b1:00.0, compute capability: 6.1
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1000)           │         9,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1000)           │     1,001,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1000)           │     1,001,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1000)           │     1,001,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │         1,001 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,013,001 (11.49 MB)
#  Trainable params: 3,013,001 (11.49 MB)
#  Non-trainable params: 0 (0.00 B)
# Using Callbacks
# Epoch 1/100
# 2025-11-04 19:13:01.207706: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-11-04 19:13:01.400737: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 24s 8ms/step - binary_accuracy: 0.7123 - loss: 6.0019e-07 - val_binary_accuracy: 0.7252 - val_loss: 5.8717e-07 - learning_rate: 0.1000
# Epoch 2/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7319 - loss: 5.7492e-07 - val_binary_accuracy: 0.7388 - val_loss: 5.6115e-07 - learning_rate: 0.1000
# Epoch 3/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7420 - loss: 5.5660e-07 - val_binary_accuracy: 0.7438 - val_loss: 5.5250e-07 - learning_rate: 0.1000
# Epoch 4/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7462 - loss: 5.5060e-07 - val_binary_accuracy: 0.7447 - val_loss: 5.5013e-07 - learning_rate: 0.1000
# Epoch 5/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7481 - loss: 5.4720e-07 - val_binary_accuracy: 0.7471 - val_loss: 5.4792e-07 - learning_rate: 0.1000
# Epoch 6/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7503 - loss: 5.4367e-07 - val_binary_accuracy: 0.7523 - val_loss: 5.4009e-07 - learning_rate: 0.1000
# Epoch 7/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7535 - loss: 5.3936e-07 - val_binary_accuracy: 0.7546 - val_loss: 5.3704e-07 - learning_rate: 0.1000
# Epoch 8/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7553 - loss: 5.3663e-07 - val_binary_accuracy: 0.7551 - val_loss: 5.3737e-07 - learning_rate: 0.1000
# Epoch 9/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7565 - loss: 5.3487e-07 - val_binary_accuracy: 0.7563 - val_loss: 5.3480e-07 - learning_rate: 0.1000
# Epoch 10/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7574 - loss: 5.3354e-07 - val_binary_accuracy: 0.7571 - val_loss: 5.3431e-07 - learning_rate: 0.1000
# Epoch 11/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7578 - loss: 5.3261e-07 - val_binary_accuracy: 0.7557 - val_loss: 5.3332e-07 - learning_rate: 0.1000
# Epoch 12/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7583 - loss: 5.3159e-07 - val_binary_accuracy: 0.7581 - val_loss: 5.3074e-07 - learning_rate: 0.1000
# Epoch 13/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7592 - loss: 5.3067e-07 - val_binary_accuracy: 0.7585 - val_loss: 5.3018e-07 - learning_rate: 0.1000
# Epoch 14/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7595 - loss: 5.2993e-07 - val_binary_accuracy: 0.7569 - val_loss: 5.3289e-07 - learning_rate: 0.1000
# Epoch 15/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7600 - loss: 5.2905e-07 - val_binary_accuracy: 0.7604 - val_loss: 5.2737e-07 - learning_rate: 0.1000
# Epoch 16/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7606 - loss: 5.2842e-07 - val_binary_accuracy: 0.7589 - val_loss: 5.2985e-07 - learning_rate: 0.1000
# Epoch 17/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7609 - loss: 5.2767e-07 - val_binary_accuracy: 0.7571 - val_loss: 5.3501e-07 - learning_rate: 0.1000
# Epoch 18/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7616 - loss: 5.2687e-07 - val_binary_accuracy: 0.7606 - val_loss: 5.2739e-07 - learning_rate: 0.1000
# Epoch 19/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7619 - loss: 5.2619e-07 - val_binary_accuracy: 0.7603 - val_loss: 5.2848e-07 - learning_rate: 0.1000
# Epoch 20/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7622 - loss: 5.2582e-07 - val_binary_accuracy: 0.7597 - val_loss: 5.2855e-07 - learning_rate: 0.1000
# Epoch 21/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7623 - loss: 5.2538e-07 - val_binary_accuracy: 0.7625 - val_loss: 5.2614e-07 - learning_rate: 0.1000
# Epoch 22/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7625 - loss: 5.2499e-07 - val_binary_accuracy: 0.7623 - val_loss: 5.2553e-07 - learning_rate: 0.1000
# Epoch 23/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7631 - loss: 5.2453e-07 - val_binary_accuracy: 0.7616 - val_loss: 5.2644e-07 - learning_rate: 0.1000
# Epoch 24/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7631 - loss: 5.2408e-07 - val_binary_accuracy: 0.7624 - val_loss: 5.2567e-07 - learning_rate: 0.1000
# Epoch 25/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7635 - loss: 5.2367e-07 - val_binary_accuracy: 0.7624 - val_loss: 5.2602e-07 - learning_rate: 0.1000
# Epoch 26/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7635 - loss: 5.2344e-07 - val_binary_accuracy: 0.7597 - val_loss: 5.2805e-07 - learning_rate: 0.1000
# Epoch 27/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7640 - loss: 5.2296e-07 - val_binary_accuracy: 0.7612 - val_loss: 5.2761e-07 - learning_rate: 0.1000
# Epoch 28/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7638 - loss: 5.2281e-07 - val_binary_accuracy: 0.7632 - val_loss: 5.2312e-07 - learning_rate: 0.1000
# Epoch 29/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7637 - loss: 5.2277e-07 - val_binary_accuracy: 0.7623 - val_loss: 5.2488e-07 - learning_rate: 0.1000
# Epoch 30/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7641 - loss: 5.2240e-07 - val_binary_accuracy: 0.7626 - val_loss: 5.2389e-07 - learning_rate: 0.1000
# Epoch 31/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7644 - loss: 5.2210e-07 - val_binary_accuracy: 0.7634 - val_loss: 5.2274e-07 - learning_rate: 0.1000
# Epoch 32/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7669 - loss: 5.1772e-07 - val_binary_accuracy: 0.7650 - val_loss: 5.1929e-07 - learning_rate: 0.0010
# Epoch 33/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7671 - loss: 5.1695e-07 - val_binary_accuracy: 0.7652 - val_loss: 5.1896e-07 - learning_rate: 0.0010
# Epoch 34/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7673 - loss: 5.1675e-07 - val_binary_accuracy: 0.7652 - val_loss: 5.1890e-07 - learning_rate: 0.0010
# Epoch 35/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7672 - loss: 5.1664e-07 - val_binary_accuracy: 0.7653 - val_loss: 5.1883e-07 - learning_rate: 0.0010
# Epoch 36/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7673 - loss: 5.1656e-07 - val_binary_accuracy: 0.7655 - val_loss: 5.1875e-07 - learning_rate: 0.0010
# Epoch 37/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7673 - loss: 5.1650e-07 - val_binary_accuracy: 0.7655 - val_loss: 5.1880e-07 - learning_rate: 0.0010
# Epoch 38/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7674 - loss: 5.1645e-07 - val_binary_accuracy: 0.7656 - val_loss: 5.1873e-07 - learning_rate: 0.0010
# Epoch 39/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7675 - loss: 5.1641e-07 - val_binary_accuracy: 0.7654 - val_loss: 5.1866e-07 - learning_rate: 0.0010
# Epoch 40/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7675 - loss: 5.1638e-07 - val_binary_accuracy: 0.7655 - val_loss: 5.1865e-07 - learning_rate: 0.0010
# Epoch 41/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7675 - loss: 5.1634e-07 - val_binary_accuracy: 0.7652 - val_loss: 5.1861e-07 - learning_rate: 0.0010
# Epoch 42/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7675 - loss: 5.1633e-07 - val_binary_accuracy: 0.7655 - val_loss: 5.1864e-07 - learning_rate: 0.0010
# Epoch 43/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7675 - loss: 5.1630e-07 - val_binary_accuracy: 0.7651 - val_loss: 5.1863e-07 - learning_rate: 0.0010
# Epoch 44/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7676 - loss: 5.1627e-07 - val_binary_accuracy: 0.7652 - val_loss: 5.1866e-07 - learning_rate: 0.0010
# Epoch 45/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7676 - loss: 5.1624e-07 - val_binary_accuracy: 0.7655 - val_loss: 5.1866e-07 - learning_rate: 0.0010
# Epoch 46/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7676 - loss: 5.1623e-07 - val_binary_accuracy: 0.7653 - val_loss: 5.1854e-07 - learning_rate: 0.0010
# Epoch 47/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7677 - loss: 5.1620e-07 - val_binary_accuracy: 0.7654 - val_loss: 5.1862e-07 - learning_rate: 0.0010
# Epoch 48/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7676 - loss: 5.1619e-07 - val_binary_accuracy: 0.7655 - val_loss: 5.1866e-07 - learning_rate: 0.0010
# Epoch 49/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7677 - loss: 5.1617e-07 - val_binary_accuracy: 0.7652 - val_loss: 5.1859e-07 - learning_rate: 0.0010
# Epoch 50/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7677 - loss: 5.1614e-07 - val_binary_accuracy: 0.7655 - val_loss: 5.1867e-07 - learning_rate: 0.0010
# Epoch 51/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7677 - loss: 5.1614e-07 - val_binary_accuracy: 0.7651 - val_loss: 5.1861e-07 - learning_rate: 0.0010
# Epoch 52/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7677 - loss: 5.1612e-07 - val_binary_accuracy: 0.7654 - val_loss: 5.1854e-07 - learning_rate: 0.0010
# Epoch 53/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7676 - loss: 5.1611e-07 - val_binary_accuracy: 0.7656 - val_loss: 5.1850e-07 - learning_rate: 0.0010
# Epoch 54/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7677 - loss: 5.1610e-07 - val_binary_accuracy: 0.7654 - val_loss: 5.1853e-07 - learning_rate: 0.0010
# Epoch 55/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7677 - loss: 5.1608e-07 - val_binary_accuracy: 0.7653 - val_loss: 5.1850e-07 - learning_rate: 0.0010
# Epoch 56/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7677 - loss: 5.1606e-07 - val_binary_accuracy: 0.7653 - val_loss: 5.1861e-07 - learning_rate: 0.0010
# Epoch 57/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7678 - loss: 5.1605e-07 - val_binary_accuracy: 0.7653 - val_loss: 5.1855e-07 - learning_rate: 0.0010
# Epoch 58/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7677 - loss: 5.1604e-07 - val_binary_accuracy: 0.7657 - val_loss: 5.1857e-07 - learning_rate: 0.0010
# Epoch 59/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7678 - loss: 5.1604e-07 - val_binary_accuracy: 0.7654 - val_loss: 5.1854e-07 - learning_rate: 0.0010
# Epoch 60/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7678 - loss: 5.1601e-07 - val_binary_accuracy: 0.7654 - val_loss: 5.1854e-07 - learning_rate: 0.0010
# Epoch 61/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7679 - loss: 5.1600e-07 - val_binary_accuracy: 0.7655 - val_loss: 5.1844e-07 - learning_rate: 0.0010
# Epoch 62/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7678 - loss: 5.1595e-07 - val_binary_accuracy: 0.7654 - val_loss: 5.1842e-07 - learning_rate: 1.0000e-05
# Epoch 63/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7678 - loss: 5.1592e-07 - val_binary_accuracy: 0.7655 - val_loss: 5.1842e-07 - learning_rate: 1.0000e-05
# Epoch 64/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7678 - loss: 5.1591e-07 - val_binary_accuracy: 0.7655 - val_loss: 5.1843e-07 - learning_rate: 1.0000e-05
# Epoch 65/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7678 - loss: 5.1590e-07 - val_binary_accuracy: 0.7655 - val_loss: 5.1843e-07 - learning_rate: 1.0000e-05
# Epoch 66/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7678 - loss: 5.1590e-07 - val_binary_accuracy: 0.7655 - val_loss: 5.1843e-07 - learning_rate: 1.0000e-05
# Epoch 67/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7678 - loss: 5.1590e-07 - val_binary_accuracy: 0.7654 - val_loss: 5.1843e-07 - learning_rate: 1.0000e-05
# Epoch 68/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7678 - loss: 5.1590e-07 - val_binary_accuracy: 0.7655 - val_loss: 5.1843e-07 - learning_rate: 1.0000e-05
# Epoch 69/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7678 - loss: 5.1590e-07 - val_binary_accuracy: 0.7655 - val_loss: 5.1843e-07 - learning_rate: 1.0000e-05
# Epoch 70/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7678 - loss: 5.1589e-07 - val_binary_accuracy: 0.7655 - val_loss: 5.1843e-07 - learning_rate: 1.0000e-05
# Epoch 71/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7678 - loss: 5.1589e-07 - val_binary_accuracy: 0.7655 - val_loss: 5.1843e-07 - learning_rate: 1.0000e-05
# Epoch 72/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7678 - loss: 5.1589e-07 - val_binary_accuracy: 0.7655 - val_loss: 5.1843e-07 - learning_rate: 1.0000e-05
# Epoch 73/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7678 - loss: 5.1589e-07 - val_binary_accuracy: 0.7655 - val_loss: 5.1843e-07 - learning_rate: 1.0000e-05
# Epoch 74/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7678 - loss: 5.1589e-07 - val_binary_accuracy: 0.7655 - val_loss: 5.1843e-07 - learning_rate: 1.0000e-05
# Epoch 75/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7678 - loss: 5.1589e-07 - val_binary_accuracy: 0.7655 - val_loss: 5.1843e-07 - learning_rate: 1.0000e-05
# Epoch 76/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7678 - loss: 5.1589e-07 - val_binary_accuracy: 0.7655 - val_loss: 5.1843e-07 - learning_rate: 1.0000e-05
# Epoch 77/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7678 - loss: 5.1589e-07 - val_binary_accuracy: 0.7655 - val_loss: 5.1843e-07 - learning_rate: 1.0000e-05
# Epoch 78/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7678 - loss: 5.1589e-07 - val_binary_accuracy: 0.7655 - val_loss: 5.1843e-07 - learning_rate: 1.0000e-05
# Epoch 79/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7678 - loss: 5.1589e-07 - val_binary_accuracy: 0.7655 - val_loss: 5.1843e-07 - learning_rate: 1.0000e-05
# Epoch 80/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7678 - loss: 5.1589e-07 - val_binary_accuracy: 0.7655 - val_loss: 5.1843e-07 - learning_rate: 1.0000e-05
# Epoch 81/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7678 - loss: 5.1589e-07 - val_binary_accuracy: 0.7655 - val_loss: 5.1844e-07 - learning_rate: 1.0000e-05
# Epoch 82/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7678 - loss: 5.1589e-07 - val_binary_accuracy: 0.7655 - val_loss: 5.1844e-07 - learning_rate: 1.0000e-05
# Epoch 83/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7678 - loss: 5.1589e-07 - val_binary_accuracy: 0.7654 - val_loss: 5.1844e-07 - learning_rate: 1.0000e-05
# Epoch 84/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7678 - loss: 5.1589e-07 - val_binary_accuracy: 0.7654 - val_loss: 5.1844e-07 - learning_rate: 1.0000e-05
# Epoch 85/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7678 - loss: 5.1589e-07 - val_binary_accuracy: 0.7654 - val_loss: 5.1844e-07 - learning_rate: 1.0000e-05
# Epoch 86/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7678 - loss: 5.1589e-07 - val_binary_accuracy: 0.7654 - val_loss: 5.1844e-07 - learning_rate: 1.0000e-05
# Epoch 87/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7678 - loss: 5.1589e-07 - val_binary_accuracy: 0.7654 - val_loss: 5.1844e-07 - learning_rate: 1.0000e-05
# Epoch 88/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7678 - loss: 5.1589e-07 - val_binary_accuracy: 0.7654 - val_loss: 5.1844e-07 - learning_rate: 1.0000e-05
# Epoch 89/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7678 - loss: 5.1589e-07 - val_binary_accuracy: 0.7654 - val_loss: 5.1844e-07 - learning_rate: 1.0000e-05
# Epoch 90/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7678 - loss: 5.1589e-07 - val_binary_accuracy: 0.7654 - val_loss: 5.1844e-07 - learning_rate: 1.0000e-05
# Epoch 91/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7678 - loss: 5.1589e-07 - val_binary_accuracy: 0.7654 - val_loss: 5.1844e-07 - learning_rate: 1.0000e-05
# Epoch 92/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7678 - loss: 5.1589e-07 - val_binary_accuracy: 0.7654 - val_loss: 5.1844e-07 - learning_rate: 1.0000e-07
# Epoch 93/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7678 - loss: 5.1589e-07 - val_binary_accuracy: 0.7654 - val_loss: 5.1844e-07 - learning_rate: 1.0000e-07
# Epoch 94/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7678 - loss: 5.1589e-07 - val_binary_accuracy: 0.7654 - val_loss: 5.1844e-07 - learning_rate: 1.0000e-07
# Epoch 95/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7678 - loss: 5.1589e-07 - val_binary_accuracy: 0.7654 - val_loss: 5.1844e-07 - learning_rate: 1.0000e-07
# Epoch 96/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7678 - loss: 5.1589e-07 - val_binary_accuracy: 0.7654 - val_loss: 5.1844e-07 - learning_rate: 1.0000e-07
# Epoch 97/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7678 - loss: 5.1589e-07 - val_binary_accuracy: 0.7654 - val_loss: 5.1844e-07 - learning_rate: 1.0000e-07
# Epoch 98/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7678 - loss: 5.1589e-07 - val_binary_accuracy: 0.7654 - val_loss: 5.1844e-07 - learning_rate: 1.0000e-07
# Epoch 99/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7678 - loss: 5.1589e-07 - val_binary_accuracy: 0.7654 - val_loss: 5.1844e-07 - learning_rate: 1.0000e-07
# Epoch 100/100
# 2539/2539 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - binary_accuracy: 0.7678 - loss: 5.1589e-07 - val_binary_accuracy: 0.7654 - val_loss: 5.1844e-07 - learning_rate: 1.0000e-07
# Finished Training
# 2025-11-04 19:43:08.323528: I tensorflow/core/grappler/clusters/single_machine.cc:361] Starting new session
# 2025-11-04 19:43:08.326598: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10525 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:b1:00.0, compute capability: 6.1
# 2025-11-04 19:43:08.521722: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10525 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:b1:00.0, compute capability: 6.1
# 2025-11-04 19:43:08.547245: I tensorflow/core/grappler/clusters/single_machine.cc:361] Starting new session
# 2025-11-04 19:43:08.550295: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10525 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:b1:00.0, compute capability: 6.1
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# The sum of PDFs in ensemble member 0 is 1.0063556595354866
#
#
# The sum of PDFs using the whole ensemble is 1.0063556595354866
#
#
#
# starting ensemble training
# Sum of weights of class 0: 0.7496058344841003
# Sum of weights of class 1: 0.7499990463256836
# Using swish activation function
# /home/jsandesara_umass_edu/NSBI-workflow-tutorial/.pixi/envs/nsbi-env-gpu/lib/python3.12/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1000)           │         9,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1000)           │     1,001,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1000)           │     1,001,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1000)           │     1,001,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │         1,001 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,013,001 (11.49 MB)
#  Trainable params: 3,013,001 (11.49 MB)
#  Non-trainable params: 0 (0.00 B)
# Using Callbacks
# Epoch 1/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - binary_accuracy: 0.8944 - loss: 6.1843e-07 - val_binary_accuracy: 0.9020 - val_loss: 5.9068e-07 - learning_rate: 0.1000
# Epoch 2/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9030 - loss: 5.7432e-07 - val_binary_accuracy: 0.9059 - val_loss: 5.7281e-07 - learning_rate: 0.1000
# Epoch 3/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9040 - loss: 5.6673e-07 - val_binary_accuracy: 0.9056 - val_loss: 5.6916e-07 - learning_rate: 0.1000
# Epoch 4/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9047 - loss: 5.6154e-07 - val_binary_accuracy: 0.9052 - val_loss: 5.7136e-07 - learning_rate: 0.1000
# Epoch 5/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9064 - loss: 5.5474e-07 - val_binary_accuracy: 0.9072 - val_loss: 5.6543e-07 - learning_rate: 0.1000
# Epoch 6/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9079 - loss: 5.4907e-07 - val_binary_accuracy: 0.9102 - val_loss: 5.5102e-07 - learning_rate: 0.1000
# Epoch 7/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9088 - loss: 5.4374e-07 - val_binary_accuracy: 0.9096 - val_loss: 5.4976e-07 - learning_rate: 0.1000
# Epoch 8/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9092 - loss: 5.4058e-07 - val_binary_accuracy: 0.9107 - val_loss: 5.4557e-07 - learning_rate: 0.1000
# Epoch 9/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9096 - loss: 5.3824e-07 - val_binary_accuracy: 0.9099 - val_loss: 5.5128e-07 - learning_rate: 0.1000
# Epoch 10/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9101 - loss: 5.3644e-07 - val_binary_accuracy: 0.9108 - val_loss: 5.4134e-07 - learning_rate: 0.1000
# Epoch 11/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9103 - loss: 5.3480e-07 - val_binary_accuracy: 0.9120 - val_loss: 5.4134e-07 - learning_rate: 0.1000
# Epoch 12/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9109 - loss: 5.3324e-07 - val_binary_accuracy: 0.9109 - val_loss: 5.4519e-07 - learning_rate: 0.1000
# Epoch 13/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9108 - loss: 5.3195e-07 - val_binary_accuracy: 0.9122 - val_loss: 5.3794e-07 - learning_rate: 0.1000
# Epoch 14/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9113 - loss: 5.3056e-07 - val_binary_accuracy: 0.9123 - val_loss: 5.3530e-07 - learning_rate: 0.1000
# Epoch 15/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9114 - loss: 5.2950e-07 - val_binary_accuracy: 0.9105 - val_loss: 5.4561e-07 - learning_rate: 0.1000
# Epoch 16/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9112 - loss: 5.2909e-07 - val_binary_accuracy: 0.9107 - val_loss: 5.4042e-07 - learning_rate: 0.1000
# Epoch 17/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9116 - loss: 5.2811e-07 - val_binary_accuracy: 0.9128 - val_loss: 5.3382e-07 - learning_rate: 0.1000
# Epoch 18/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9121 - loss: 5.2732e-07 - val_binary_accuracy: 0.9120 - val_loss: 5.3384e-07 - learning_rate: 0.1000
# Epoch 19/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9122 - loss: 5.2618e-07 - val_binary_accuracy: 0.9121 - val_loss: 5.3444e-07 - learning_rate: 0.1000
# Epoch 20/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9121 - loss: 5.2566e-07 - val_binary_accuracy: 0.9121 - val_loss: 5.3828e-07 - learning_rate: 0.1000
# Epoch 21/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9121 - loss: 5.2496e-07 - val_binary_accuracy: 0.9128 - val_loss: 5.3283e-07 - learning_rate: 0.1000
# Epoch 22/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9124 - loss: 5.2421e-07 - val_binary_accuracy: 0.9124 - val_loss: 5.3240e-07 - learning_rate: 0.1000
# Epoch 23/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9127 - loss: 5.2337e-07 - val_binary_accuracy: 0.9124 - val_loss: 5.3314e-07 - learning_rate: 0.1000
# Epoch 24/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9128 - loss: 5.2285e-07 - val_binary_accuracy: 0.9129 - val_loss: 5.3291e-07 - learning_rate: 0.1000
# Epoch 25/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9128 - loss: 5.2252e-07 - val_binary_accuracy: 0.9114 - val_loss: 5.3668e-07 - learning_rate: 0.1000
# Epoch 26/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9127 - loss: 5.2226e-07 - val_binary_accuracy: 0.9132 - val_loss: 5.2794e-07 - learning_rate: 0.1000
# Epoch 27/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9129 - loss: 5.2101e-07 - val_binary_accuracy: 0.9127 - val_loss: 5.3146e-07 - learning_rate: 0.1000
# Epoch 28/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9135 - loss: 5.2034e-07 - val_binary_accuracy: 0.9128 - val_loss: 5.3207e-07 - learning_rate: 0.1000
# Epoch 29/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9131 - loss: 5.2030e-07 - val_binary_accuracy: 0.9126 - val_loss: 5.2989e-07 - learning_rate: 0.1000
# Epoch 30/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9132 - loss: 5.1978e-07 - val_binary_accuracy: 0.9120 - val_loss: 5.3325e-07 - learning_rate: 0.1000
# Epoch 31/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9133 - loss: 5.1945e-07 - val_binary_accuracy: 0.9137 - val_loss: 5.2848e-07 - learning_rate: 0.1000
# Epoch 32/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9145 - loss: 5.1299e-07 - val_binary_accuracy: 0.9146 - val_loss: 5.2209e-07 - learning_rate: 0.0010
# Epoch 33/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9149 - loss: 5.1064e-07 - val_binary_accuracy: 0.9146 - val_loss: 5.2107e-07 - learning_rate: 0.0010
# Epoch 34/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9151 - loss: 5.1004e-07 - val_binary_accuracy: 0.9145 - val_loss: 5.2079e-07 - learning_rate: 0.0010
# Epoch 35/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9150 - loss: 5.0971e-07 - val_binary_accuracy: 0.9144 - val_loss: 5.2070e-07 - learning_rate: 0.0010
# Epoch 36/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9151 - loss: 5.0950e-07 - val_binary_accuracy: 0.9141 - val_loss: 5.2043e-07 - learning_rate: 0.0010
# Epoch 37/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9151 - loss: 5.0933e-07 - val_binary_accuracy: 0.9143 - val_loss: 5.2063e-07 - learning_rate: 0.0010
# Epoch 38/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9152 - loss: 5.0924e-07 - val_binary_accuracy: 0.9142 - val_loss: 5.2037e-07 - learning_rate: 0.0010
# Epoch 39/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9151 - loss: 5.0915e-07 - val_binary_accuracy: 0.9143 - val_loss: 5.2072e-07 - learning_rate: 0.0010
# Epoch 40/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9152 - loss: 5.0903e-07 - val_binary_accuracy: 0.9143 - val_loss: 5.2042e-07 - learning_rate: 0.0010
# Epoch 41/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9152 - loss: 5.0897e-07 - val_binary_accuracy: 0.9141 - val_loss: 5.2043e-07 - learning_rate: 0.0010
# Epoch 42/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9152 - loss: 5.0889e-07 - val_binary_accuracy: 0.9143 - val_loss: 5.2012e-07 - learning_rate: 0.0010
# Epoch 43/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9152 - loss: 5.0885e-07 - val_binary_accuracy: 0.9144 - val_loss: 5.2021e-07 - learning_rate: 0.0010
# Epoch 44/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9153 - loss: 5.0878e-07 - val_binary_accuracy: 0.9141 - val_loss: 5.2025e-07 - learning_rate: 0.0010
# Epoch 45/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9152 - loss: 5.0876e-07 - val_binary_accuracy: 0.9140 - val_loss: 5.2023e-07 - learning_rate: 0.0010
# Epoch 46/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9152 - loss: 5.0870e-07 - val_binary_accuracy: 0.9142 - val_loss: 5.2025e-07 - learning_rate: 0.0010
# Epoch 47/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9152 - loss: 5.0864e-07 - val_binary_accuracy: 0.9143 - val_loss: 5.2020e-07 - learning_rate: 0.0010
# Epoch 48/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9153 - loss: 5.0861e-07 - val_binary_accuracy: 0.9142 - val_loss: 5.2002e-07 - learning_rate: 0.0010
# Epoch 49/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9154 - loss: 5.0859e-07 - val_binary_accuracy: 0.9144 - val_loss: 5.2027e-07 - learning_rate: 0.0010
# Epoch 50/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9153 - loss: 5.0854e-07 - val_binary_accuracy: 0.9144 - val_loss: 5.2002e-07 - learning_rate: 0.0010
# Epoch 51/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9153 - loss: 5.0851e-07 - val_binary_accuracy: 0.9142 - val_loss: 5.2001e-07 - learning_rate: 0.0010
# Epoch 52/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9153 - loss: 5.0846e-07 - val_binary_accuracy: 0.9144 - val_loss: 5.1998e-07 - learning_rate: 0.0010
# Epoch 53/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9153 - loss: 5.0845e-07 - val_binary_accuracy: 0.9141 - val_loss: 5.2010e-07 - learning_rate: 0.0010
# Epoch 54/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9153 - loss: 5.0839e-07 - val_binary_accuracy: 0.9143 - val_loss: 5.2010e-07 - learning_rate: 0.0010
# Epoch 55/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9153 - loss: 5.0837e-07 - val_binary_accuracy: 0.9141 - val_loss: 5.1992e-07 - learning_rate: 0.0010
# Epoch 56/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9153 - loss: 5.0833e-07 - val_binary_accuracy: 0.9141 - val_loss: 5.2004e-07 - learning_rate: 0.0010
# Epoch 57/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9154 - loss: 5.0830e-07 - val_binary_accuracy: 0.9145 - val_loss: 5.1991e-07 - learning_rate: 0.0010
# Epoch 58/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9153 - loss: 5.0829e-07 - val_binary_accuracy: 0.9143 - val_loss: 5.1990e-07 - learning_rate: 0.0010
# Epoch 59/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9154 - loss: 5.0826e-07 - val_binary_accuracy: 0.9143 - val_loss: 5.2011e-07 - learning_rate: 0.0010
# Epoch 60/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9154 - loss: 5.0823e-07 - val_binary_accuracy: 0.9144 - val_loss: 5.2012e-07 - learning_rate: 0.0010
# Epoch 61/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9154 - loss: 5.0821e-07 - val_binary_accuracy: 0.9145 - val_loss: 5.1980e-07 - learning_rate: 0.0010
# Epoch 62/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9154 - loss: 5.0802e-07 - val_binary_accuracy: 0.9146 - val_loss: 5.1981e-07 - learning_rate: 1.0000e-05
# Epoch 63/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9154 - loss: 5.0802e-07 - val_binary_accuracy: 0.9145 - val_loss: 5.1982e-07 - learning_rate: 1.0000e-05
# Epoch 64/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9154 - loss: 5.0802e-07 - val_binary_accuracy: 0.9145 - val_loss: 5.1982e-07 - learning_rate: 1.0000e-05
# Epoch 65/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9154 - loss: 5.0801e-07 - val_binary_accuracy: 0.9144 - val_loss: 5.1983e-07 - learning_rate: 1.0000e-05
# Epoch 66/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9154 - loss: 5.0801e-07 - val_binary_accuracy: 0.9144 - val_loss: 5.1984e-07 - learning_rate: 1.0000e-05
# Epoch 67/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9154 - loss: 5.0801e-07 - val_binary_accuracy: 0.9144 - val_loss: 5.1984e-07 - learning_rate: 1.0000e-05
# Epoch 68/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9154 - loss: 5.0801e-07 - val_binary_accuracy: 0.9145 - val_loss: 5.1984e-07 - learning_rate: 1.0000e-05
# Epoch 69/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9154 - loss: 5.0800e-07 - val_binary_accuracy: 0.9145 - val_loss: 5.1985e-07 - learning_rate: 1.0000e-05
# Epoch 70/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9154 - loss: 5.0800e-07 - val_binary_accuracy: 0.9144 - val_loss: 5.1985e-07 - learning_rate: 1.0000e-05
# Epoch 71/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9154 - loss: 5.0800e-07 - val_binary_accuracy: 0.9145 - val_loss: 5.1985e-07 - learning_rate: 1.0000e-05
# Epoch 72/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9154 - loss: 5.0800e-07 - val_binary_accuracy: 0.9145 - val_loss: 5.1985e-07 - learning_rate: 1.0000e-05
# Epoch 73/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9154 - loss: 5.0800e-07 - val_binary_accuracy: 0.9144 - val_loss: 5.1985e-07 - learning_rate: 1.0000e-05
# Epoch 74/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9154 - loss: 5.0800e-07 - val_binary_accuracy: 0.9144 - val_loss: 5.1985e-07 - learning_rate: 1.0000e-05
# Epoch 75/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9154 - loss: 5.0800e-07 - val_binary_accuracy: 0.9144 - val_loss: 5.1985e-07 - learning_rate: 1.0000e-05
# Epoch 76/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9154 - loss: 5.0800e-07 - val_binary_accuracy: 0.9144 - val_loss: 5.1986e-07 - learning_rate: 1.0000e-05
# Epoch 77/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9154 - loss: 5.0800e-07 - val_binary_accuracy: 0.9144 - val_loss: 5.1986e-07 - learning_rate: 1.0000e-05
# Epoch 78/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9154 - loss: 5.0800e-07 - val_binary_accuracy: 0.9143 - val_loss: 5.1986e-07 - learning_rate: 1.0000e-05
# Epoch 79/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9154 - loss: 5.0800e-07 - val_binary_accuracy: 0.9144 - val_loss: 5.1986e-07 - learning_rate: 1.0000e-05
# Epoch 80/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9154 - loss: 5.0800e-07 - val_binary_accuracy: 0.9144 - val_loss: 5.1986e-07 - learning_rate: 1.0000e-05
# Epoch 81/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9154 - loss: 5.0800e-07 - val_binary_accuracy: 0.9144 - val_loss: 5.1986e-07 - learning_rate: 1.0000e-05
# Epoch 82/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9154 - loss: 5.0799e-07 - val_binary_accuracy: 0.9144 - val_loss: 5.1986e-07 - learning_rate: 1.0000e-05
# Epoch 83/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9154 - loss: 5.0799e-07 - val_binary_accuracy: 0.9144 - val_loss: 5.1986e-07 - learning_rate: 1.0000e-05
# Epoch 84/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9154 - loss: 5.0799e-07 - val_binary_accuracy: 0.9144 - val_loss: 5.1986e-07 - learning_rate: 1.0000e-05
# Epoch 85/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9154 - loss: 5.0799e-07 - val_binary_accuracy: 0.9144 - val_loss: 5.1986e-07 - learning_rate: 1.0000e-05
# Epoch 86/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9154 - loss: 5.0799e-07 - val_binary_accuracy: 0.9144 - val_loss: 5.1986e-07 - learning_rate: 1.0000e-05
# Epoch 87/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9154 - loss: 5.0799e-07 - val_binary_accuracy: 0.9144 - val_loss: 5.1986e-07 - learning_rate: 1.0000e-05
# Epoch 88/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9154 - loss: 5.0799e-07 - val_binary_accuracy: 0.9144 - val_loss: 5.1986e-07 - learning_rate: 1.0000e-05
# Epoch 89/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9154 - loss: 5.0799e-07 - val_binary_accuracy: 0.9144 - val_loss: 5.1986e-07 - learning_rate: 1.0000e-05
# Epoch 90/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9154 - loss: 5.0799e-07 - val_binary_accuracy: 0.9144 - val_loss: 5.1986e-07 - learning_rate: 1.0000e-05
# Epoch 91/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9154 - loss: 5.0799e-07 - val_binary_accuracy: 0.9144 - val_loss: 5.1986e-07 - learning_rate: 1.0000e-05
# Epoch 92/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9154 - loss: 5.0799e-07 - val_binary_accuracy: 0.9144 - val_loss: 5.1986e-07 - learning_rate: 1.0000e-07
# Epoch 93/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9154 - loss: 5.0799e-07 - val_binary_accuracy: 0.9144 - val_loss: 5.1986e-07 - learning_rate: 1.0000e-07
# Epoch 94/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9154 - loss: 5.0799e-07 - val_binary_accuracy: 0.9144 - val_loss: 5.1986e-07 - learning_rate: 1.0000e-07
# Epoch 95/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9154 - loss: 5.0799e-07 - val_binary_accuracy: 0.9144 - val_loss: 5.1986e-07 - learning_rate: 1.0000e-07
# Epoch 96/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9154 - loss: 5.0799e-07 - val_binary_accuracy: 0.9144 - val_loss: 5.1986e-07 - learning_rate: 1.0000e-07
# Epoch 97/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9154 - loss: 5.0799e-07 - val_binary_accuracy: 0.9144 - val_loss: 5.1986e-07 - learning_rate: 1.0000e-07
# Epoch 98/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9154 - loss: 5.0799e-07 - val_binary_accuracy: 0.9144 - val_loss: 5.1986e-07 - learning_rate: 1.0000e-07
# Epoch 99/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9154 - loss: 5.0799e-07 - val_binary_accuracy: 0.9144 - val_loss: 5.1986e-07 - learning_rate: 1.0000e-07
# Epoch 100/100
# 1129/1129 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - binary_accuracy: 0.9154 - loss: 5.0799e-07 - val_binary_accuracy: 0.9144 - val_loss: 5.1986e-07 - learning_rate: 1.0000e-07
# Finished Training
# 2025-11-04 19:56:54.793184: I tensorflow/core/grappler/clusters/single_machine.cc:361] Starting new session
# 2025-11-04 19:56:54.796150: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10525 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:b1:00.0, compute capability: 6.1
# 2025-11-04 19:56:55.016330: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10525 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:b1:00.0, compute capability: 6.1
# 2025-11-04 19:56:55.039756: I tensorflow/core/grappler/clusters/single_machine.cc:361] Starting new session
# 2025-11-04 19:56:55.042743: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10525 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:b1:00.0, compute capability: 6.1
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# The sum of PDFs in ensemble member 0 is 0.9937831444856609
#
#
# The sum of PDFs using the whole ensemble is 0.9937831444856609
#
#
#
# starting ensemble training
# Sum of weights of class 0: 0.7497962713241577
# Sum of weights of class 1: 0.7499999403953552
# Using swish activation function
# /home/jsandesara_umass_edu/NSBI-workflow-tutorial/.pixi/envs/nsbi-env-gpu/lib/python3.12/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1000)           │         9,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1000)           │     1,001,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1000)           │     1,001,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1000)           │     1,001,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │         1,001 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,013,001 (11.49 MB)
#  Trainable params: 3,013,001 (11.49 MB)
#  Non-trainable params: 0 (0.00 B)
# Using Callbacks
# Epoch 1/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 17s 9ms/step - binary_accuracy: 0.5024 - loss: 1.1861e-06 - val_binary_accuracy: 0.5067 - val_loss: 1.1850e-06 - learning_rate: 0.1000
# Epoch 2/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5042 - loss: 1.1858e-06 - val_binary_accuracy: 0.5064 - val_loss: 1.1848e-06 - learning_rate: 0.1000
# Epoch 3/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5027 - loss: 1.1858e-06 - val_binary_accuracy: 0.5031 - val_loss: 1.1848e-06 - learning_rate: 0.1000
# Epoch 4/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5038 - loss: 1.1858e-06 - val_binary_accuracy: 0.5013 - val_loss: 1.1852e-06 - learning_rate: 0.1000
# Epoch 5/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5035 - loss: 1.1858e-06 - val_binary_accuracy: 0.5003 - val_loss: 1.1861e-06 - learning_rate: 0.1000
# Epoch 6/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5040 - loss: 1.1857e-06 - val_binary_accuracy: 0.5077 - val_loss: 1.1848e-06 - learning_rate: 0.1000
# Epoch 7/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5036 - loss: 1.1858e-06 - val_binary_accuracy: 0.5013 - val_loss: 1.1850e-06 - learning_rate: 0.1000
# Epoch 8/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5040 - loss: 1.1857e-06 - val_binary_accuracy: 0.5057 - val_loss: 1.1847e-06 - learning_rate: 0.1000
# Epoch 9/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5032 - loss: 1.1857e-06 - val_binary_accuracy: 0.5084 - val_loss: 1.1847e-06 - learning_rate: 0.1000
# Epoch 10/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5029 - loss: 1.1857e-06 - val_binary_accuracy: 0.5006 - val_loss: 1.1852e-06 - learning_rate: 0.1000
# Epoch 11/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5027 - loss: 1.1856e-06 - val_binary_accuracy: 0.5082 - val_loss: 1.1847e-06 - learning_rate: 0.1000
# Epoch 12/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5043 - loss: 1.1856e-06 - val_binary_accuracy: 0.5077 - val_loss: 1.1847e-06 - learning_rate: 0.1000
# Epoch 13/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5037 - loss: 1.1854e-06 - val_binary_accuracy: 0.5003 - val_loss: 1.1849e-06 - learning_rate: 0.1000
# Epoch 14/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5038 - loss: 1.1853e-06 - val_binary_accuracy: 0.5004 - val_loss: 1.1846e-06 - learning_rate: 0.1000
# Epoch 15/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5028 - loss: 1.1852e-06 - val_binary_accuracy: 0.5059 - val_loss: 1.1849e-06 - learning_rate: 0.1000
# Epoch 16/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5038 - loss: 1.1851e-06 - val_binary_accuracy: 0.5003 - val_loss: 1.1843e-06 - learning_rate: 0.1000
# Epoch 17/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5026 - loss: 1.1851e-06 - val_binary_accuracy: 0.5094 - val_loss: 1.1841e-06 - learning_rate: 0.1000
# Epoch 18/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5038 - loss: 1.1851e-06 - val_binary_accuracy: 0.5003 - val_loss: 1.1849e-06 - learning_rate: 0.1000
# Epoch 19/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5038 - loss: 1.1850e-06 - val_binary_accuracy: 0.5003 - val_loss: 1.1846e-06 - learning_rate: 0.1000
# ...
# Epoch 21/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5049 - loss: 1.1850e-06 - val_binary_accuracy: 0.5070 - val_loss: 1.1841e-06 - learning_rate: 0.1000
# Epoch 22/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5036 - loss: 1.1850e-06 - val_binary_accuracy: 0.5054 - val_loss: 1.1855e-06 - learning_rate: 0.1000
# Epoch 23/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5037 - loss: 1.1849e-06 - val_binary_accuracy: 0.5003 - val_loss: 1.1845e-06 - learning_rate: 0.1000
# Epoch 24/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5035 - loss: 1.1849e-06 - val_binary_accuracy: 0.5067 - val_loss: 1.1842e-06 - learning_rate: 0.1000
# Epoch 25/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5049 - loss: 1.1848e-06 - val_binary_accuracy: 0.5068 - val_loss: 1.1839e-06 - learning_rate: 0.1000
# Epoch 26/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5043 - loss: 1.1849e-06 - val_binary_accuracy: 0.5088 - val_loss: 1.1838e-06 - learning_rate: 0.1000
# Epoch 27/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5043 - loss: 1.1848e-06 - val_binary_accuracy: 0.5061 - val_loss: 1.1838e-06 - learning_rate: 0.1000
# Epoch 28/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5032 - loss: 1.1848e-06 - val_binary_accuracy: 0.5087 - val_loss: 1.1837e-06 - learning_rate: 0.1000
# Epoch 29/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5032 - loss: 1.1848e-06 - val_binary_accuracy: 0.5065 - val_loss: 1.1840e-06 - learning_rate: 0.1000
# Epoch 30/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5040 - loss: 1.1847e-06 - val_binary_accuracy: 0.5003 - val_loss: 1.1842e-06 - learning_rate: 0.1000
# Epoch 31/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5036 - loss: 1.1847e-06 - val_binary_accuracy: 0.5054 - val_loss: 1.1853e-06 - learning_rate: 0.1000
# Epoch 32/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5057 - loss: 1.1845e-06 - val_binary_accuracy: 0.5061 - val_loss: 1.1837e-06 - learning_rate: 0.0010
# Epoch 33/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5061 - loss: 1.1844e-06 - val_binary_accuracy: 0.5066 - val_loss: 1.1837e-06 - learning_rate: 0.0010
# Epoch 34/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5062 - loss: 1.1844e-06 - val_binary_accuracy: 0.5062 - val_loss: 1.1837e-06 - learning_rate: 0.0010
# Epoch 35/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5060 - loss: 1.1844e-06 - val_binary_accuracy: 0.5065 - val_loss: 1.1837e-06 - learning_rate: 0.0010
# Epoch 36/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5060 - loss: 1.1844e-06 - val_binary_accuracy: 0.5066 - val_loss: 1.1837e-06 - learning_rate: 0.0010
# Epoch 37/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5059 - loss: 1.1844e-06 - val_binary_accuracy: 0.5066 - val_loss: 1.1837e-06 - learning_rate: 0.0010
# Epoch 38/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5060 - loss: 1.1844e-06 - val_binary_accuracy: 0.5067 - val_loss: 1.1837e-06 - learning_rate: 0.0010
# Epoch 39/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5059 - loss: 1.1844e-06 - val_binary_accuracy: 0.5067 - val_loss: 1.1837e-06 - learning_rate: 0.0010
# Epoch 40/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5060 - loss: 1.1844e-06 - val_binary_accuracy: 0.5066 - val_loss: 1.1837e-06 - learning_rate: 0.0010
# Epoch 41/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5061 - loss: 1.1844e-06 - val_binary_accuracy: 0.5067 - val_loss: 1.1837e-06 - learning_rate: 0.0010
# Epoch 42/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5060 - loss: 1.1844e-06 - val_binary_accuracy: 0.5060 - val_loss: 1.1837e-06 - learning_rate: 0.0010
# Epoch 43/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5061 - loss: 1.1844e-06 - val_binary_accuracy: 0.5067 - val_loss: 1.1837e-06 - learning_rate: 0.0010
# Epoch 44/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5060 - loss: 1.1844e-06 - val_binary_accuracy: 0.5067 - val_loss: 1.1837e-06 - learning_rate: 0.0010
# Epoch 45/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5059 - loss: 1.1844e-06 - val_binary_accuracy: 0.5061 - val_loss: 1.1837e-06 - learning_rate: 0.0010
# Epoch 46/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5060 - loss: 1.1844e-06 - val_binary_accuracy: 0.5067 - val_loss: 1.1837e-06 - learning_rate: 0.0010
# Epoch 47/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5060 - loss: 1.1844e-06 - val_binary_accuracy: 0.5064 - val_loss: 1.1837e-06 - learning_rate: 0.0010
# Epoch 48/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5061 - loss: 1.1844e-06 - val_binary_accuracy: 0.5066 - val_loss: 1.1837e-06 - learning_rate: 0.0010
# Epoch 49/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5061 - loss: 1.1844e-06 - val_binary_accuracy: 0.5068 - val_loss: 1.1837e-06 - learning_rate: 0.0010
# Epoch 50/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5058 - loss: 1.1844e-06 - val_binary_accuracy: 0.5060 - val_loss: 1.1837e-06 - learning_rate: 0.0010
# Epoch 51/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5060 - loss: 1.1844e-06 - val_binary_accuracy: 0.5062 - val_loss: 1.1837e-06 - learning_rate: 0.0010
# Epoch 52/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5060 - loss: 1.1844e-06 - val_binary_accuracy: 0.5061 - val_loss: 1.1837e-06 - learning_rate: 0.0010
# Epoch 53/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5060 - loss: 1.1844e-06 - val_binary_accuracy: 0.5067 - val_loss: 1.1837e-06 - learning_rate: 0.0010
# Epoch 54/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5061 - loss: 1.1844e-06 - val_binary_accuracy: 0.5062 - val_loss: 1.1837e-06 - learning_rate: 0.0010
# Epoch 55/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5060 - loss: 1.1844e-06 - val_binary_accuracy: 0.5069 - val_loss: 1.1837e-06 - learning_rate: 0.0010
# Epoch 56/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5061 - loss: 1.1844e-06 - val_binary_accuracy: 0.5064 - val_loss: 1.1837e-06 - learning_rate: 0.0010
# Epoch 57/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5059 - loss: 1.1844e-06 - val_binary_accuracy: 0.5067 - val_loss: 1.1837e-06 - learning_rate: 0.0010
# Epoch 58/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5061 - loss: 1.1844e-06 - val_binary_accuracy: 0.5070 - val_loss: 1.1837e-06 - learning_rate: 0.0010
# Epoch 59/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5060 - loss: 1.1844e-06 - val_binary_accuracy: 0.5069 - val_loss: 1.1837e-06 - learning_rate: 0.0010
# Epoch 60/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5060 - loss: 1.1844e-06 - val_binary_accuracy: 0.5064 - val_loss: 1.1837e-06 - learning_rate: 0.0010
# Epoch 61/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5059 - loss: 1.1844e-06 - val_binary_accuracy: 0.5064 - val_loss: 1.1837e-06 - learning_rate: 0.0010
# Epoch 62/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5060 - loss: 1.1844e-06 - val_binary_accuracy: 0.5064 - val_loss: 1.1837e-06 - learning_rate: 1.0000e-05
# Epoch 63/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5060 - loss: 1.1844e-06 - val_binary_accuracy: 0.5064 - val_loss: 1.1837e-06 - learning_rate: 1.0000e-05
# Epoch 64/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5060 - loss: 1.1844e-06 - val_binary_accuracy: 0.5064 - val_loss: 1.1837e-06 - learning_rate: 1.0000e-05
# Epoch 65/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5060 - loss: 1.1844e-06 - val_binary_accuracy: 0.5063 - val_loss: 1.1837e-06 - learning_rate: 1.0000e-05
# Epoch 66/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5060 - loss: 1.1844e-06 - val_binary_accuracy: 0.5064 - val_loss: 1.1837e-06 - learning_rate: 1.0000e-05
# Epoch 67/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5060 - loss: 1.1844e-06 - val_binary_accuracy: 0.5064 - val_loss: 1.1837e-06 - learning_rate: 1.0000e-05
# Epoch 68/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5060 - loss: 1.1844e-06 - val_binary_accuracy: 0.5064 - val_loss: 1.1837e-06 - learning_rate: 1.0000e-05
# Epoch 69/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5060 - loss: 1.1844e-06 - val_binary_accuracy: 0.5063 - val_loss: 1.1837e-06 - learning_rate: 1.0000e-05
# Epoch 70/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5060 - loss: 1.1844e-06 - val_binary_accuracy: 0.5063 - val_loss: 1.1837e-06 - learning_rate: 1.0000e-05
# Epoch 71/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5060 - loss: 1.1844e-06 - val_binary_accuracy: 0.5063 - val_loss: 1.1837e-06 - learning_rate: 1.0000e-05
# Epoch 72/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5060 - loss: 1.1844e-06 - val_binary_accuracy: 0.5064 - val_loss: 1.1837e-06 - learning_rate: 1.0000e-05
# Epoch 73/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5060 - loss: 1.1844e-06 - val_binary_accuracy: 0.5064 - val_loss: 1.1837e-06 - learning_rate: 1.0000e-05
# Epoch 74/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5060 - loss: 1.1844e-06 - val_binary_accuracy: 0.5064 - val_loss: 1.1837e-06 - learning_rate: 1.0000e-05
# Epoch 75/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5060 - loss: 1.1844e-06 - val_binary_accuracy: 0.5065 - val_loss: 1.1837e-06 - learning_rate: 1.0000e-05
# Epoch 76/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5060 - loss: 1.1844e-06 - val_binary_accuracy: 0.5066 - val_loss: 1.1837e-06 - learning_rate: 1.0000e-05
# Epoch 77/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5060 - loss: 1.1844e-06 - val_binary_accuracy: 0.5067 - val_loss: 1.1837e-06 - learning_rate: 1.0000e-05
# Epoch 78/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5060 - loss: 1.1844e-06 - val_binary_accuracy: 0.5068 - val_loss: 1.1837e-06 - learning_rate: 1.0000e-05
# Epoch 79/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5060 - loss: 1.1844e-06 - val_binary_accuracy: 0.5068 - val_loss: 1.1837e-06 - learning_rate: 1.0000e-05
# Epoch 80/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5060 - loss: 1.1844e-06 - val_binary_accuracy: 0.5067 - val_loss: 1.1837e-06 - learning_rate: 1.0000e-05
# Epoch 81/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5060 - loss: 1.1844e-06 - val_binary_accuracy: 0.5067 - val_loss: 1.1837e-06 - learning_rate: 1.0000e-05
# Epoch 82/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5060 - loss: 1.1844e-06 - val_binary_accuracy: 0.5068 - val_loss: 1.1837e-06 - learning_rate: 1.0000e-05
# Epoch 83/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5060 - loss: 1.1844e-06 - val_binary_accuracy: 0.5068 - val_loss: 1.1837e-06 - learning_rate: 1.0000e-05
# Epoch 84/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5060 - loss: 1.1844e-06 - val_binary_accuracy: 0.5068 - val_loss: 1.1837e-06 - learning_rate: 1.0000e-05
# Epoch 85/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5060 - loss: 1.1844e-06 - val_binary_accuracy: 0.5068 - val_loss: 1.1837e-06 - learning_rate: 1.0000e-05
# Epoch 86/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5060 - loss: 1.1844e-06 - val_binary_accuracy: 0.5068 - val_loss: 1.1837e-06 - learning_rate: 1.0000e-05
# Epoch 87/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5060 - loss: 1.1844e-06 - val_binary_accuracy: 0.5068 - val_loss: 1.1837e-06 - learning_rate: 1.0000e-05
# Epoch 88/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5060 - loss: 1.1844e-06 - val_binary_accuracy: 0.5068 - val_loss: 1.1837e-06 - learning_rate: 1.0000e-05
# Epoch 89/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5060 - loss: 1.1844e-06 - val_binary_accuracy: 0.5068 - val_loss: 1.1837e-06 - learning_rate: 1.0000e-05
# Epoch 90/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5060 - loss: 1.1844e-06 - val_binary_accuracy: 0.5068 - val_loss: 1.1837e-06 - learning_rate: 1.0000e-05
# Epoch 91/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5060 - loss: 1.1844e-06 - val_binary_accuracy: 0.5068 - val_loss: 1.1837e-06 - learning_rate: 1.0000e-05
# Epoch 92/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5060 - loss: 1.1844e-06 - val_binary_accuracy: 0.5068 - val_loss: 1.1837e-06 - learning_rate: 1.0000e-07
# Epoch 93/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5060 - loss: 1.1844e-06 - val_binary_accuracy: 0.5068 - val_loss: 1.1837e-06 - learning_rate: 1.0000e-07
# Epoch 94/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5060 - loss: 1.1844e-06 - val_binary_accuracy: 0.5068 - val_loss: 1.1837e-06 - learning_rate: 1.0000e-07
# Epoch 95/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5060 - loss: 1.1844e-06 - val_binary_accuracy: 0.5068 - val_loss: 1.1837e-06 - learning_rate: 1.0000e-07
# Epoch 96/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5060 - loss: 1.1844e-06 - val_binary_accuracy: 0.5068 - val_loss: 1.1837e-06 - learning_rate: 1.0000e-07
# Epoch 97/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5060 - loss: 1.1844e-06 - val_binary_accuracy: 0.5068 - val_loss: 1.1837e-06 - learning_rate: 1.0000e-07
# Epoch 98/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5060 - loss: 1.1844e-06 - val_binary_accuracy: 0.5068 - val_loss: 1.1837e-06 - learning_rate: 1.0000e-07
# Epoch 99/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5060 - loss: 1.1844e-06 - val_binary_accuracy: 0.5068 - val_loss: 1.1837e-06 - learning_rate: 1.0000e-07
# Epoch 100/100
# 1542/1542 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - binary_accuracy: 0.5060 - loss: 1.1844e-06 - val_binary_accuracy: 0.5068 - val_loss: 1.1837e-06 - learning_rate: 1.0000e-07
# Finished Training
# 2025-11-04 20:15:34.560846: I tensorflow/core/grappler/clusters/single_machine.cc:361] Starting new session
# 2025-11-04 20:15:34.564025: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10525 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:b1:00.0, compute capability: 6.1
# 2025-11-04 20:15:34.778691: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10525 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:b1:00.0, compute capability: 6.1
# 2025-11-04 20:15:34.802310: I tensorflow/core/grappler/clusters/single_machine.cc:361] Starting new session
# 2025-11-04 20:15:34.805331: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10525 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:b1:00.0, compute capability: 6.1
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# The sum of PDFs in ensemble member 0 is 1.0003240004792675
#
#
# The sum of PDFs using the whole ensemble is 1.0003240004792675

# %% [markdown]
# Check for overtraining by comparing the NN output distributions between training and holdout datasets. The holdout dataset is the subset of events not used during training.

# %%
for process_type in basis_processes:
    NN_training_mix_model[process_type].make_overfit_plots()

# %% [markdown]
# Diagnostic Checks
# ===
#
# While traditionally, a NN observable is judged on the basis of its accuracy - for NSBI we are interested in the quality of the density ratios more than the discrimination power. The latter comes from the perfect modelling of the multi-dimensional likelihood ratios.
#
# To ensure correct modelling, we run two main checks on the training:
#
# - **Calibration closure test**
#
#   The NNs are trained using the binary cross-entropy loss, which under ideal conditions leads to the NN converging to the score function:
#
#   $$\hat{s}_\text{pred} = \frac{p_\text{ref}(x)}{p_\text{ref}(x)+p_\text{c}(x)}$$
#
#   that can be converted into the probability ratio we desire (likelihood ratio trick):
#
#   $$\frac{p_\text{c}(x)}{p_\text{ref}(x)} = \frac{\hat{s}_\text{pred}(x)}{1-\hat{s}_\text{pred}(x)}$$
#
#   For the NNs to be well-calibrated, we use the Monte Carlo samples to verify the equality:
#
#
#   $$\left[\frac{p_c(x)}{p_c(x)+p_{ref}(x)}\right]_\text{NN} \sim \left[\frac{\mathcal{N}_c^{I(x|\hat{s}_\text{pred})}}{\mathcal{N}_c^{I(x|\hat{s}_\text{pred})}+\mathcal{N}_\text{ref}^{I(x|\hat{s}_\text{pred})}}\right]_\text{MC}$$
#
#   where we bin the events from $p_c$ and $p_\text{ref}$ MC samples, denoted by $\mathcal{N}_c^{I(x|\hat{s}_\text{pred})}$ and $\mathcal{N}_\text{ref}^{I(x|\hat{s}_\text{pred})}$ respectively where $I(x|\hat{s}_\text{pred})$ returns the index of the $\hat{s}_\text{pred}$ bin in which an event $x$ falls.

# %%
num_bins_cal = 50

for process_type in basis_processes:
    NN_training_mix_model[process_type].make_calib_plots(nbins=num_bins_cal, observable='score')

# %%
num_bins_cal = 50

for process_type in basis_processes:
    NN_training_mix_model[process_type].make_calib_plots(nbins=num_bins_cal, observable='llr')

# %% [markdown]
# ## Density ratio reweighting closure tests
#
#   Despite having a well-calibrated output and thus a robust probabilistic interpretation, the trained density ratios might not capture the full multi-dimensional event information $x$. In other words, the NNs might still be biased estimators of the optimal score function, as defined in the CARL paper (link).
#
#   The next diagnostic involves verifying the following equality using 1D projections of $x$:
#
#   $$\frac{p_c(x)}{p_{ref}(x)} \times p_{ref}(x) \sim p_c(x)$$
#
#   We can do this one-by-one for all the observables used to model the density ratios, and also possibly the observables not used directly in the training but can still be well-estimated due to the NN learning the right physics.

# %%
variables_to_plot=['log_DER_pt_h'] # The 1D variable for reweighting closure
yscale_type='log'
num_bins_plotting=21

for process_type in basis_processes:

    NN_training_mix_model[process_type].make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)

# %%
dataset_combined_SR = Datasets.merge_dataframe_dict_for_training(dataset_SR_nominal, None, 
                                                                samples_to_merge = ["htautau", "ztautau", "ttbar"])

# %%
path_to_saved_ratios = {}

for process_type in basis_processes:
    # Evaluate the density ratios p_c/p_ref for the full dataset and save for the inference step
    path_to_saved_ratios[process_type] = NN_training_mix_model[process_type].evaluate_and_save_ratios(dataset_combined_SR, 
                                                                                                     aggregation_type = 'median_score')
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Evaluating density ratios
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# Evaluating density ratios
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
# Density ratio paths to put in the config file
path_to_saved_ratios
# Out:
# {'htautau': './saved_datasets/output_training_nominal/output_ratios_htautau/ratio_htautau.npy',
#  'ttbar': './saved_datasets/output_training_nominal/output_ratios_ttbar/ratio_ttbar.npy',
#  'ztautau': './saved_datasets/output_training_nominal/output_ratios_ztautau/ratio_ztautau.npy'}

# %%
# Optionally save the dataframe in the same order used to evaluate the density ratios for diagnostics

path_to_save = f"{PATH_TO_SAVED_DATA}/dataset_Asimov.root"
nsbi_common_utils.datasets.save_dataframe_as_root(dataset_combined_SR, 
                                                  path_to_save = path_to_save,
                                                  tree_name = "nominal")

# %%
# Asimov weights correspond to the expected weight vector in the same shape and order as the evaluated density ratios
# This is used in the weighted NLL fits for expected sensitivity and coverage computations

path_to_save = f"{PATH_TO_SAVED_DATA}/asimov_weights.npy"
np.save(f"{path_to_save}", dataset_combined_SR["weights"].to_numpy())

# %%
# Path to put in the config file for inference
path_to_save
# Out:
# './saved_datasets//asimov_weights.npy'

# %% [markdown]
# Systematic Uncertainty Modelling
# ===
#
# So far we have left out the nuisance parameter piece of the parameterized density ratio decomposition shown before:
#
# $$g_c(x|\alpha) = \frac{p_c(x|\alpha)}{p_c(x)}$$
#
# which will be estimated in the `Systematic_Uncertainty_Estimation.ipynb` notebook.

# %% [markdown]
# Training an Ensemble of NNs
# ===
#
# In a realistic analysis, a large ensemble of NNs are trained to estimate density ratios, for *each* of the channels. **This reduces not only the variance but has also been found to reduce biases in the final fits.**
#
# In the off-shell Higgs boson analysis, we used k-fold cross-validation, with k=10, to train an ensemble $N_{ens}\sim 250$ of NNs per density ratio $p_c(x)/p_{ref}(x)$. The density ratios used in the final fit are always evaluated on the holdout dataset and by using each of the folds as holdout once, the entire model for $p_c(x)/p_{ref}(x)$ consists of $N_{ens}\times k \sim 2500$ NNs. Each NN in the ensemble is trained by resampling data without replacement from the k-1 folds used for training.
